# %%
import requests
from api import api_key
import pprint
import json
import pandas as pd

# %%
#extract language data from endpoint

url = "https://api.themoviedb.org/3/configuration/languages"

headers = {
    "accept": "application/json",
    "Authorization": api_key
}

response = requests.get(url, headers=headers).json()

print(json.dumps(response, indent=4))
# Out:
# [
#     {
#         "iso_639_1": "xx",
#         "english_name": "No Language",
#         "name": "No Language"
#     },
#     {
#         "iso_639_1": "aa",
#         "english_name": "Afar",
#         "name": ""
#     },
#     {
#         "iso_639_1": "af",
#         "english_name": "Afrikaans",
#         "name": "Afrikaans"
#     },
#     {
#         "iso_639_1": "ak",
#         "english_name": "Akan",
#         "name": ""
#     },
#     {
#         "iso_639_1": "an",
#         "english_name": "Aragonese",
#         "name": ""
#     },
#     {
#         "iso_639_1": "as",
#         "english_name": "Assamese",
#         "name": ""
#     },
#     {
#         "iso_639_1": "av",
#         "english_name": "Avaric",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ae",
#         "english_name": "Avestan",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ay",
#         "english_name": "Aymara",
#         "name": ""
#     },
#     {
#         "iso_639_1": "az",
#         "english_name": "Azerbaijani",
#         "name": "Az\u0259rbaycan"
#     },
#     {
#         "iso_639_1": "ba",
#         "english_name": "Bashkir",
#         "name": ""
#     },
#     {
#         "iso_639_1": "bm",
#         "english_name": "Bambara",
#         "name": "Bamanankan"
#     },
#     {
#         "iso_639_1": "bi",
#         "english_name": "Bislama",
#         "name": ""
#     },
#     {
#         "iso_639_1": "bo",
#         "english_name": "Tibetan",
#         "name": ""
#     },
#     {
#         "iso_639_1": "br",
#         "english_name": "Breton",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ca",
#         "english_name": "Catalan",
#         "name": "Catal\u00e0"
#     },
#     {
#         "iso_639_1": "cs",
#         "english_name": "Czech",
#         "name": "\u010cesk\u00fd"
#     },
#     {
#         "iso_639_1": "ce",
#         "english_name": "Chechen",
#         "name": ""
#     },
#     {
#         "iso_639_1": "cu",
#         "english_name": "Slavic",
#         "name": ""
#     },
#     {
#         "iso_639_1": "cv",
#         "english_name": "Chuvash",
#         "name": ""
#     },
#     {
#         "iso_639_1": "kw",
#         "english_name": "Cornish",
#         "name": ""
#     },
#     {
#         "iso_639_1": "co",
#         "english_name": "Corsican",
#         "name": ""
#     },
#     {
#         "iso_639_1": "cr",
#         "english_name": "Cree",
#         "name": ""
#     },
#     {
#         "iso_639_1": "cy",
#         "english_name": "Welsh",
#         "name": "Cymraeg"
#     },
#     {
#         "iso_639_1": "da",
#         "english_name": "Danish",
#         "name": "Dansk"
#     },
#     {
#         "iso_639_1": "de",
#         "english_name": "German",
#         "name": "Deutsch"
#     },
#     {
#         "iso_639_1": "dv",
#         "english_name": "Divehi",
#         "name": ""
#     },
#     {
#         "iso_639_1": "dz",
#         "english_name": "Dzongkha",
#         "name": ""
#     },
#     {
#         "iso_639_1": "eo",
#         "english_name": "Esperanto",
#         "name": "Esperanto"
#     },
#     {
#         "iso_639_1": "et",
#         "english_name": "Estonian",
#         "name": "Eesti"
#     },
#     {
#         "iso_639_1": "eu",
#         "english_name": "Basque",
#         "name": "euskera"
#     },
#     {
#         "iso_639_1": "fo",
#         "english_name": "Faroese",
#         "name": ""
#     },
#     {
#         "iso_639_1": "fj",
#         "english_name": "Fijian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "fi",
#         "english_name": "Finnish",
#         "name": "suomi"
#     },
#     {
#         "iso_639_1": "fr",
#         "english_name": "French",
#         "name": "Fran\u00e7ais"
#     },
#     {
#         "iso_639_1": "fy",
#         "english_name": "Frisian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ff",
#         "english_name": "Fulah",
#         "name": "Fulfulde"
#     },
#     {
#         "iso_639_1": "gd",
#         "english_name": "Gaelic",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ga",
#         "english_name": "Irish",
#         "name": "Gaeilge"
#     },
#     {
#         "iso_639_1": "gl",
#         "english_name": "Galician",
#         "name": "Galego"
#     },
#     {
#         "iso_639_1": "gv",
#         "english_name": "Manx",
#         "name": ""
#     },
#     {
#         "iso_639_1": "gn",
#         "english_name": "Guarani",
#         "name": ""
#     },
#     {
#         "iso_639_1": "gu",
#         "english_name": "Gujarati",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ht",
#         "english_name": "Haitian; Haitian Creole",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ha",
#         "english_name": "Hausa",
#         "name": "Hausa"
#     },
#     {
#         "iso_639_1": "sh",
#         "english_name": "Serbo-Croatian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "hz",
#         "english_name": "Herero",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ho",
#         "english_name": "Hiri Motu",
#         "name": ""
#     },
#     {
#         "iso_639_1": "hr",
#         "english_name": "Croatian",
#         "name": "Hrvatski"
#     },
#     {
#         "iso_639_1": "hu",
#         "english_name": "Hungarian",
#         "name": "Magyar"
#     },
#     {
#         "iso_639_1": "ig",
#         "english_name": "Igbo",
#         "name": ""
#     },
#     {
#         "iso_639_1": "io",
#         "english_name": "Ido",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ii",
#         "english_name": "Yi",
#         "name": ""
#     },
#     {
#         "iso_639_1": "iu",
#         "english_name": "Inuktitut",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ie",
#         "english_name": "Interlingue",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ia",
#         "english_name": "Interlingua",
#         "name": ""
#     },
#     {
#         "iso_639_1": "id",
#         "english_name": "Indonesian",
#         "name": "Bahasa indonesia"
#     },
#     {
#         "iso_639_1": "ik",
#         "english_name": "Inupiaq",
#         "name": ""
#     },
#     {
#         "iso_639_1": "is",
#         "english_name": "Icelandic",
#         "name": "\u00cdslenska"
#     },
#     {
#         "iso_639_1": "it",
#         "english_name": "Italian",
#         "name": "Italiano"
#     },
#     {
#         "iso_639_1": "jv",
#         "english_name": "Javanese",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ja",
#         "english_name": "Japanese",
#         "name": "\u65e5\u672c\u8a9e"
#     },
#     {
#         "iso_639_1": "kl",
#         "english_name": "Kalaallisut",
#         "name": ""
#     },
#     {
#         "iso_639_1": "kn",
#         "english_name": "Kannada",
#         "name": "?????"
#     },
#     {
#         "iso_639_1": "ks",
#         "english_name": "Kashmiri",
#         "name": ""
#     },
#     {
#         "iso_639_1": "kr",
#         "english_name": "Kanuri",
#         "name": ""
#     },
#     {
#         "iso_639_1": "kk",
#         "english_name": "Kazakh",
#         "name": "\u049b\u0430\u0437\u0430\u049b"
#     },
#     {
#         "iso_639_1": "km",
#         "english_name": "Khmer",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ki",
#         "english_name": "Kikuyu",
#         "name": ""
#     },
#     {
#         "iso_639_1": "rw",
#         "english_name": "Kinyarwanda",
#         "name": "Kinyarwanda"
#     },
#     {
#         "iso_639_1": "ky",
#         "english_name": "Kirghiz",
#         "name": "??????"
#     },
#     {
#         "iso_639_1": "kv",
#         "english_name": "Komi",
#         "name": ""
#     },
#     {
#         "iso_639_1": "kg",
#         "english_name": "Kongo",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ko",
#         "english_name": "Korean",
#         "name": "\ud55c\uad6d\uc5b4/\uc870\uc120\ub9d0"
#     },
#     {
#         "iso_639_1": "kj",
#         "english_name": "Kuanyama",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ku",
#         "english_name": "Kurdish",
#         "name": ""
#     },
#     {
#         "iso_639_1": "lo",
#         "english_name": "Lao",
#         "name": ""
#     },
#     {
#         "iso_639_1": "la",
#         "english_name": "Latin",
#         "name": "Latin"
#     },
#     {
#         "iso_639_1": "lv",
#         "english_name": "Latvian",
#         "name": "Latvie\u0161u"
#     },
#     {
#         "iso_639_1": "li",
#         "english_name": "Limburgish",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ln",
#         "english_name": "Lingala",
#         "name": ""
#     },
#     {
#         "iso_639_1": "lt",
#         "english_name": "Lithuanian",
#         "name": "Lietuvi\u0173"
#     },
#     {
#         "iso_639_1": "lb",
#         "english_name": "Letzeburgesch",
#         "name": ""
#     },
#     {
#         "iso_639_1": "lu",
#         "english_name": "Luba-Katanga",
#         "name": ""
#     },
#     {
#         "iso_639_1": "lg",
#         "english_name": "Ganda",
#         "name": ""
#     },
#     {
#         "iso_639_1": "mh",
#         "english_name": "Marshall",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ml",
#         "english_name": "Malayalam",
#         "name": ""
#     },
#     {
#         "iso_639_1": "mr",
#         "english_name": "Marathi",
#         "name": ""
#     },
#     {
#         "iso_639_1": "mg",
#         "english_name": "Malagasy",
#         "name": ""
#     },
#     {
#         "iso_639_1": "mt",
#         "english_name": "Maltese",
#         "name": "Malti"
#     },
#     {
#         "iso_639_1": "mo",
#         "english_name": "Moldavian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "mn",
#         "english_name": "Mongolian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "mi",
#         "english_name": "Maori",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ms",
#         "english_name": "Malay",
#         "name": "Bahasa melayu"
#     },
#     {
#         "iso_639_1": "my",
#         "english_name": "Burmese",
#         "name": ""
#     },
#     {
#         "iso_639_1": "na",
#         "english_name": "Nauru",
#         "name": ""
#     },
#     {
#         "iso_639_1": "nv",
#         "english_name": "Navajo",
#         "name": ""
#     },
#     {
#         "iso_639_1": "nr",
#         "english_name": "Ndebele",
#         "name": ""
#     },
#     {
#         "iso_639_1": "nd",
#         "english_name": "Ndebele",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ng",
#         "english_name": "Ndonga",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ne",
#         "english_name": "Nepali",
#         "name": ""
#     },
#     {
#         "iso_639_1": "nl",
#         "english_name": "Dutch",
#         "name": "Nederlands"
#     },
#     {
#         "iso_639_1": "nn",
#         "english_name": "Norwegian Nynorsk",
#         "name": ""
#     },
#     {
#         "iso_639_1": "nb",
#         "english_name": "Norwegian Bokm\u00e5l",
#         "name": "Bokm\u00e5l"
#     },
#     {
#         "iso_639_1": "no",
#         "english_name": "Norwegian",
#         "name": "Norsk"
#     },
#     {
#         "iso_639_1": "ny",
#         "english_name": "Chichewa; Nyanja",
#         "name": ""
#     },
#     {
#         "iso_639_1": "oc",
#         "english_name": "Occitan",
#         "name": ""
#     },
#     {
#         "iso_639_1": "oj",
#         "english_name": "Ojibwa",
#         "name": ""
#     },
#     {
#         "iso_639_1": "or",
#         "english_name": "Oriya",
#         "name": ""
#     },
#     {
#         "iso_639_1": "om",
#         "english_name": "Oromo",
#         "name": ""
#     },
#     {
#         "iso_639_1": "os",
#         "english_name": "Ossetian; Ossetic",
#         "name": ""
#     },
#     {
#         "iso_639_1": "pi",
#         "english_name": "Pali",
#         "name": ""
#     },
#     {
#         "iso_639_1": "pl",
#         "english_name": "Polish",
#         "name": "Polski"
#     },
#     {
#         "iso_639_1": "pt",
#         "english_name": "Portuguese",
#         "name": "Portugu\u00eas"
#     },
#     {
#         "iso_639_1": "qu",
#         "english_name": "Quechua",
#         "name": ""
#     },
#     {
#         "iso_639_1": "rm",
#         "english_name": "Raeto-Romance",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ro",
#         "english_name": "Romanian",
#         "name": "Rom\u00e2n\u0103"
#     },
#     {
#         "iso_639_1": "rn",
#         "english_name": "Rundi",
#         "name": "Kirundi"
#     },
#     {
#         "iso_639_1": "ru",
#         "english_name": "Russian",
#         "name": "P\u0443\u0441\u0441\u043a\u0438\u0439"
#     },
#     {
#         "iso_639_1": "sg",
#         "english_name": "Sango",
#         "name": ""
#     },
#     {
#         "iso_639_1": "sa",
#         "english_name": "Sanskrit",
#         "name": ""
#     },
#     {
#         "iso_639_1": "si",
#         "english_name": "Sinhalese",
#         "name": "\u0dc3\u0dd2\u0d82\u0dc4\u0dbd"
#     },
#     {
#         "iso_639_1": "sk",
#         "english_name": "Slovak",
#         "name": "Sloven\u010dina"
#     },
#     {
#         "iso_639_1": "sl",
#         "english_name": "Slovenian",
#         "name": "Sloven\u0161\u010dina"
#     },
#     {
#         "iso_639_1": "se",
#         "english_name": "Northern Sami",
#         "name": ""
#     },
#     {
#         "iso_639_1": "sm",
#         "english_name": "Samoan",
#         "name": ""
#     },
#     {
#         "iso_639_1": "sn",
#         "english_name": "Shona",
#         "name": ""
#     },
#     {
#         "iso_639_1": "sd",
#         "english_name": "Sindhi",
#         "name": ""
#     },
#     {
#         "iso_639_1": "so",
#         "english_name": "Somali",
#         "name": "Somali"
#     },
#     {
#         "iso_639_1": "st",
#         "english_name": "Sotho",
#         "name": ""
#     },
#     {
#         "iso_639_1": "es",
#         "english_name": "Spanish",
#         "name": "Espa\u00f1ol"
#     },
#     {
#         "iso_639_1": "sq",
#         "english_name": "Albanian",
#         "name": "shqip"
#     },
#     {
#         "iso_639_1": "sc",
#         "english_name": "Sardinian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "sr",
#         "english_name": "Serbian",
#         "name": "Srpski"
#     },
#     {
#         "iso_639_1": "ss",
#         "english_name": "Swati",
#         "name": ""
#     },
#     {
#         "iso_639_1": "su",
#         "english_name": "Sundanese",
#         "name": ""
#     },
#     {
#         "iso_639_1": "sw",
#         "english_name": "Swahili",
#         "name": "Kiswahili"
#     },
#     {
#         "iso_639_1": "sv",
#         "english_name": "Swedish",
#         "name": "svenska"
#     },
#     {
#         "iso_639_1": "ty",
#         "english_name": "Tahitian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ta",
#         "english_name": "Tamil",
#         "name": "\u0ba4\u0bae\u0bbf\u0bb4\u0bcd"
#     },
#     {
#         "iso_639_1": "tt",
#         "english_name": "Tatar",
#         "name": ""
#     },
#     {
#         "iso_639_1": "te",
#         "english_name": "Telugu",
#         "name": "\u0c24\u0c46\u0c32\u0c41\u0c17\u0c41"
#     },
#     {
#         "iso_639_1": "tg",
#         "english_name": "Tajik",
#         "name": ""
#     },
#     {
#         "iso_639_1": "tl",
#         "english_name": "Tagalog",
#         "name": ""
#     },
#     {
#         "iso_639_1": "th",
#         "english_name": "Thai",
#         "name": "\u0e20\u0e32\u0e29\u0e32\u0e44\u0e17\u0e22"
#     },
#     {
#         "iso_639_1": "ti",
#         "english_name": "Tigrinya",
#         "name": ""
#     },
#     {
#         "iso_639_1": "to",
#         "english_name": "Tonga",
#         "name": ""
#     },
#     {
#         "iso_639_1": "tn",
#         "english_name": "Tswana",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ts",
#         "english_name": "Tsonga",
#         "name": ""
#     },
#     {
#         "iso_639_1": "tk",
#         "english_name": "Turkmen",
#         "name": ""
#     },
#     {
#         "iso_639_1": "tr",
#         "english_name": "Turkish",
#         "name": "T\u00fcrk\u00e7e"
#     },
#     {
#         "iso_639_1": "tw",
#         "english_name": "Twi",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ug",
#         "english_name": "Uighur",
#         "name": ""
#     },
#     {
#         "iso_639_1": "uk",
#         "english_name": "Ukrainian",
#         "name": "\u0423\u043a\u0440\u0430\u0457\u043d\u0441\u044c\u043a\u0438\u0439"
#     },
#     {
#         "iso_639_1": "ur",
#         "english_name": "Urdu",
#         "name": "\u0627\u0631\u062f\u0648"
#     },
#     {
#         "iso_639_1": "uz",
#         "english_name": "Uzbek",
#         "name": "ozbek"
#     },
#     {
#         "iso_639_1": "ve",
#         "english_name": "Venda",
#         "name": ""
#     },
#     {
#         "iso_639_1": "vi",
#         "english_name": "Vietnamese",
#         "name": "Ti\u1ebfng Vi\u1ec7t"
#     },
#     {
#         "iso_639_1": "vo",
#         "english_name": "Volap\u00fck",
#         "name": ""
#     },
#     {
#         "iso_639_1": "wa",
#         "english_name": "Walloon",
#         "name": ""
#     },
#     {
#         "iso_639_1": "wo",
#         "english_name": "Wolof",
#         "name": "Wolof"
#     },
#     {
#         "iso_639_1": "xh",
#         "english_name": "Xhosa",
#         "name": ""
#     },
#     {
#         "iso_639_1": "yi",
#         "english_name": "Yiddish",
#         "name": ""
#     },
#     {
#         "iso_639_1": "za",
#         "english_name": "Zhuang",
#         "name": ""
#     },
#     {
#         "iso_639_1": "zu",
#         "english_name": "Zulu",
#         "name": "isiZulu"
#     },
#     {
#         "iso_639_1": "ab",
#         "english_name": "Abkhazian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "zh",
#         "english_name": "Mandarin",
#         "name": "\u666e\u901a\u8bdd"
#     },
#     {
#         "iso_639_1": "ps",
#         "english_name": "Pushto",
#         "name": "\u067e\u069a\u062a\u0648"
#     },
#     {
#         "iso_639_1": "am",
#         "english_name": "Amharic",
#         "name": ""
#     },
#     {
#         "iso_639_1": "ar",
#         "english_name": "Arabic",
#         "name": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#     },
#     {
#         "iso_639_1": "bg",
#         "english_name": "Bulgarian",
#         "name": "\u0431\u044a\u043b\u0433\u0430\u0440\u0441\u043a\u0438 \u0435\u0437\u0438\u043a"
#     },
#     {
#         "iso_639_1": "cn",
#         "english_name": "Cantonese",
#         "name": "\u5e7f\u5dde\u8bdd / \u5ee3\u5dde\u8a71"
#     },
#     {
#         "iso_639_1": "mk",
#         "english_name": "Macedonian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "el",
#         "english_name": "Greek",
#         "name": "\u03b5\u03bb\u03bb\u03b7\u03bd\u03b9\u03ba\u03ac"
#     },
#     {
#         "iso_639_1": "fa",
#         "english_name": "Persian",
#         "name": "\u0641\u0627\u0631\u0633\u06cc"
#     },
#     {
#         "iso_639_1": "he",
#         "english_name": "Hebrew",
#         "name": "\u05e2\u05b4\u05d1\u05b0\u05e8\u05b4\u05d9\u05ea"
#     },
#     {
#         "iso_639_1": "hi",
#         "english_name": "Hindi",
#         "name": "\u0939\u093f\u0928\u094d\u0926\u0940"
#     },
#     {
#         "iso_639_1": "hy",
#         "english_name": "Armenian",
#         "name": ""
#     },
#     {
#         "iso_639_1": "en",
#         "english_name": "English",
#         "name": "English"
#     },
#     {
#         "iso_639_1": "ee",
#         "english_name": "Ewe",
#         "name": "\u00c8\u028begbe"
#     },
#     {
#         "iso_639_1": "ka",
#         "english_name": "Georgian",
#         "name": "\u10e5\u10d0\u10e0\u10d7\u10e3\u10da\u10d8"
#     },
#     {
#         "iso_639_1": "pa",
#         "english_name": "Punjabi",
#         "name": "\u0a2a\u0a70\u0a1c\u0a3e\u0a2c\u0a40"
#     },
#     {
#         "iso_639_1": "bn",
#         "english_name": "Bengali",
#         "name": "\u09ac\u09be\u0982\u09b2\u09be"
#     },
#     {
#         "iso_639_1": "bs",
#         "english_name": "Bosnian",
#         "name": "Bosanski"
#     },
#     {
#         "iso_639_1": "ch",
#         "english_name": "Chamorro",
#         "name": "Finu' Chamorro"
#     },
#     {
#         "iso_639_1": "be",
#         "english_name": "Belarusian",
#         "name": "\u0431\u0435\u043b\u0430\u0440\u0443\u0441\u043a\u0430\u044f \u043c\u043e\u0432\u0430"
#     },
#     {
#         "iso_639_1": "yo",
#         "english_name": "Yoruba",
#         "name": "\u00c8d\u00e8 Yor\u00f9b\u00e1"
#     }
# ]

# %%
languages_df = pd.DataFrame(response)
languages_df
# Out:
#     iso_639_1 english_name             name
# 0          xx  No Language      No Language
# 1          aa         Afar
# 2          af    Afrikaans        Afrikaans
# 3          ak         Akan
# 4          an    Aragonese
# ..        ...          ...              ...
# 182        bn      Bengali            বাংলা
# 183        bs      Bosnian         Bosanski
# 184        ch     Chamorro   Finu' Chamorro
# 185        be   Belarusian  беларуская мова
# 186        yo       Yoruba       Èdè Yorùbá
#
# [187 rows x 3 columns]

# %%
rename_languages_df =languages_df.rename(columns={"iso_639_1": "Language_Id", "english_name": "Language"})

# %%
cleaned_languages_df = rename_languages_df.drop(columns="name")
cleaned_languages_df
# Out:
#     Language_Id     Language
# 0            xx  No Language
# 1            aa         Afar
# 2            af    Afrikaans
# 3            ak         Akan
# 4            an    Aragonese
# ..          ...          ...
# 182          bn      Bengali
# 183          bs      Bosnian
# 184          ch     Chamorro
# 185          be   Belarusian
# 186          yo       Yoruba
#
# [187 rows x 2 columns]

# %%
cleaned_languages_df.to_csv("../Outputs/Languages.csv", encoding='utf8', index=False)

# %%
# extract genres data

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": api_key
}

response = requests.get(url, headers=headers).json()
print(json.dumps(response["genres"], indent=4))
# Out:
# [
#     {
#         "id": 28,
#         "name": "Action"
#     },
#     {
#         "id": 12,
#         "name": "Adventure"
#     },
#     {
#         "id": 16,
#         "name": "Animation"
#     },
#     {
#         "id": 35,
#         "name": "Comedy"
#     },
#     {
#         "id": 80,
#         "name": "Crime"
#     },
#     {
#         "id": 99,
#         "name": "Documentary"
#     },
#     {
#         "id": 18,
#         "name": "Drama"
#     },
#     {
#         "id": 10751,
#         "name": "Family"
#     },
#     {
#         "id": 14,
#         "name": "Fantasy"
#     },
#     {
#         "id": 36,
#         "name": "History"
#     },
#     {
#         "id": 27,
#         "name": "Horror"
#     },
#     {
#         "id": 10402,
#         "name": "Music"
#     },
#     {
#         "id": 9648,
#         "name": "Mystery"
#     },
#     {
#         "id": 10749,
#         "name": "Romance"
#     },
#     {
#         "id": 878,
#         "name": "Science Fiction"
#     },
#     {
#         "id": 10770,
#         "name": "TV Movie"
#     },
#     {
#         "id": 53,
#         "name": "Thriller"
#     },
#     {
#         "id": 10752,
#         "name": "War"
#     },
#     {
#         "id": 37,
#         "name": "Western"
#     }
# ]

# %%
genres_df = pd.DataFrame(response["genres"])
genres_df
# Out:
#        id             name
# 0      28           Action
# 1      12        Adventure
# 2      16        Animation
# 3      35           Comedy
# 4      80            Crime
# 5      99      Documentary
# 6      18            Drama
# 7   10751           Family
# 8      14          Fantasy
# 9      36          History
# 10     27           Horror
# 11  10402            Music
# 12   9648          Mystery
# 13  10749          Romance
# 14    878  Science Fiction
# 15  10770         TV Movie
# 16     53         Thriller
# 17  10752              War
# 18     37          Western

# %%
cleaned_genres_df = genres_df.rename(columns={"id":"Genre_Id", "name":"Genres"})
cleaned_genres_df
# Out:
#     Genre_Id           Genres
# 0         28           Action
# 1         12        Adventure
# 2         16        Animation
# 3         35           Comedy
# 4         80            Crime
# 5         99      Documentary
# 6         18            Drama
# 7      10751           Family
# 8         14          Fantasy
# 9         36          History
# 10        27           Horror
# 11     10402            Music
# 12      9648          Mystery
# 13     10749          Romance
# 14       878  Science Fiction
# 15     10770         TV Movie
# 16        53         Thriller
# 17     10752              War
# 18        37          Western

# %%
cleaned_genres_df.to_csv("../Outputs/Genres.csv", encoding='utf8', index=False)

# %%
page_numbers = range(1,101)

movie_dict = []

start_date = "2019-01-01"


for page_number in page_numbers:
    url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&page={page_number}&primary_release_date.gte={start_date}"
                                                                                                                                            

    headers = {
        "accept": "application/json",
        "Authorization": api_key
        }

    response = requests.get(url, headers=headers).json()
    for x in range(20):
        movie_dict.append(response["results"][x])

# %%
len(movie_dict)
# Out:
# 2000

# %%
movie_df = pd.DataFrame(movie_dict)
movie_df
# Out:
#       adult                     backdrop_path            genre_ids       id  \
# 0     False  /xg27NrXi7VXCGUr7MG75UqLl6Vg.jpg  [16, 10751, 12, 35]  1022789
# 1     False  /wNAhuOZ3Zf84jCIlrcI6JhgmY5q.jpg        [28, 12, 878]   786892
# 2     False  /fqv8v6AycXKsivp1T5yKtLbGXce.jpg        [878, 12, 28]   653346
# 3     False  /gRApXuxWmO2forYTuTmcz5RaNUV.jpg     [28, 80, 53, 35]   573435
# 4     False  /aATi2PtaOQCVAquCym6OU0Z4FjY.jpg         [28, 80, 53]   704673
# ...     ...                               ...                  ...      ...
# 1995  False  /6TPZSJ06OEXeelx1U1VIAt0j9Ry.jpg         [28, 80, 53]   587996
# 1996  False   /dA34DDakXgvbjnyKocOcLJtKz0.jpg         [12, 18, 36]   739986
# 1997  False  /eevJuYAitUe6VwFN29aFwzeyeTr.jpg   [28, 16, 80, 9648]   537056
# 1998  False  /hXjK21t5S6WRR8HnG3apYpZ5lJW.jpg         [53, 27, 18]   617708
# 1999  False  /8J5GetxLHw6R380GUBEmH95dvrl.jpg      [18, 37, 10749]   963765
#
#      original_language                     original_title  \
# 0                   en                       Inside Out 2
# 1                   en            Furiosa: A Mad Max Saga
# 2                   en  Kingdom of the Planet of the Apes
# 3                   en              Bad Boys: Ride or Die
# 4                   en                    Trigger Warning
# ...                ...                                ...
# 1995                es                           Bajocero
# 1996                en                        True Spirit
# 1997                en                       Batman: Hush
# 1998                es                         La Llorona
# 1999                es              Extraña forma de vida
#
#                                                overview  popularity  \
# 0     Teenager Riley's mind headquarters is undergoi...    4128.506
# 1     As the world fell, young Furiosa is snatched f...    4115.719
# 2     Several generations in the future following Ca...    1777.192
# 3     After their late former Captain is framed, Low...    1329.004
# 4     A Special Forces commando uncovers a dangerous...    1205.913
# ...                                                 ...         ...
# 1995  When a prisoner transfer van is attacked, the ...      15.647
# 1996  When the tenacious young sailor Jessica Watson...      29.236
# 1997  A mysterious new villain known only as Hush us...      16.890
# 1998  Accused of the genocide of Mayan people, retir...      16.641
# 1999  After 25 years, an ex hired gun visits his old...      17.678
#
#                            poster_path release_date  \
# 0     /vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg   2024-06-11
# 1     /iADOJ8Zymht2JPMoy3R7xceZprc.jpg   2024-05-22
# 2     /gKkl37BQuKTanygYQG1pyYgLVgf.jpg   2024-05-08
# 3     /nP6RliHjxsz4irTKsxe8FRhKZYl.jpg   2024-06-05
# 4     /6XJM3C47iGOK9nFU6yLFCSf4U5c.jpg   2024-06-20
# ...                                ...          ...
# 1995  /oYEORVxp2ZfknTQYhEsNkv2HYss.jpg   2021-01-29
# 1996   /B7m21gukMeVK3NAuk1PLCo9C8p.jpg   2023-01-26
# 1997  /eiVQORVyVuNNZHPAELuWtlXoQsD.jpg   2019-07-19
# 1998  /2AmTEIwxy1VkcZe32Fs34S37qJ2.jpg   2019-07-25
# 1999  /1hLsR3aYCXnyRopd7JZHXI1p9Jm.jpg   2023-05-26
#
#                                   title  video  vote_average  vote_count
# 0                          Inside Out 2  False         7.710        1288
# 1               Furiosa: A Mad Max Saga  False         7.700        1688
# 2     Kingdom of the Planet of the Apes  False         6.863        1291
# 3                 Bad Boys: Ride or Die  False         7.025         477
# 4                       Trigger Warning  False         5.779         240
# ...                                 ...    ...           ...         ...
# 1995                         Below Zero  False         6.384         889
# 1996                        True Spirit  False         6.961         205
# 1997                       Batman: Hush  False         7.179         843
# 1998                         La Llorona  False         6.436         319
# 1999                Strange Way of Life  False         6.487         238
#
# [2000 rows x 14 columns]

# %%
movie_df['genre_ids'] =  movie_df['genre_ids'].astype(str).apply(lambda x: x.replace('[','').replace(']','')) 
movie_df
# Out:
#       adult                     backdrop_path          genre_ids       id  \
# 0     False  /xg27NrXi7VXCGUr7MG75UqLl6Vg.jpg  16, 10751, 12, 35  1022789
# 1     False  /wNAhuOZ3Zf84jCIlrcI6JhgmY5q.jpg        28, 12, 878   786892
# 2     False  /fqv8v6AycXKsivp1T5yKtLbGXce.jpg        878, 12, 28   653346
# 3     False  /gRApXuxWmO2forYTuTmcz5RaNUV.jpg     28, 80, 53, 35   573435
# 4     False  /aATi2PtaOQCVAquCym6OU0Z4FjY.jpg         28, 80, 53   704673
# ...     ...                               ...                ...      ...
# 1995  False  /6TPZSJ06OEXeelx1U1VIAt0j9Ry.jpg         28, 80, 53   587996
# 1996  False   /dA34DDakXgvbjnyKocOcLJtKz0.jpg         12, 18, 36   739986
# 1997  False  /eevJuYAitUe6VwFN29aFwzeyeTr.jpg   28, 16, 80, 9648   537056
# 1998  False  /hXjK21t5S6WRR8HnG3apYpZ5lJW.jpg         53, 27, 18   617708
# 1999  False  /8J5GetxLHw6R380GUBEmH95dvrl.jpg      18, 37, 10749   963765
#
#      original_language                     original_title  \
# 0                   en                       Inside Out 2
# 1                   en            Furiosa: A Mad Max Saga
# 2                   en  Kingdom of the Planet of the Apes
# 3                   en              Bad Boys: Ride or Die
# 4                   en                    Trigger Warning
# ...                ...                                ...
# 1995                es                           Bajocero
# 1996                en                        True Spirit
# 1997                en                       Batman: Hush
# 1998                es                         La Llorona
# 1999                es              Extraña forma de vida
#
#                                                overview  popularity  \
# 0     Teenager Riley's mind headquarters is undergoi...    4128.506
# 1     As the world fell, young Furiosa is snatched f...    4115.719
# 2     Several generations in the future following Ca...    1777.192
# 3     After their late former Captain is framed, Low...    1329.004
# 4     A Special Forces commando uncovers a dangerous...    1205.913
# ...                                                 ...         ...
# 1995  When a prisoner transfer van is attacked, the ...      15.647
# 1996  When the tenacious young sailor Jessica Watson...      29.236
# 1997  A mysterious new villain known only as Hush us...      16.890
# 1998  Accused of the genocide of Mayan people, retir...      16.641
# 1999  After 25 years, an ex hired gun visits his old...      17.678
#
#                            poster_path release_date  \
# 0     /vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg   2024-06-11
# 1     /iADOJ8Zymht2JPMoy3R7xceZprc.jpg   2024-05-22
# 2     /gKkl37BQuKTanygYQG1pyYgLVgf.jpg   2024-05-08
# 3     /nP6RliHjxsz4irTKsxe8FRhKZYl.jpg   2024-06-05
# 4     /6XJM3C47iGOK9nFU6yLFCSf4U5c.jpg   2024-06-20
# ...                                ...          ...
# 1995  /oYEORVxp2ZfknTQYhEsNkv2HYss.jpg   2021-01-29
# 1996   /B7m21gukMeVK3NAuk1PLCo9C8p.jpg   2023-01-26
# 1997  /eiVQORVyVuNNZHPAELuWtlXoQsD.jpg   2019-07-19
# 1998  /2AmTEIwxy1VkcZe32Fs34S37qJ2.jpg   2019-07-25
# 1999  /1hLsR3aYCXnyRopd7JZHXI1p9Jm.jpg   2023-05-26
#
#                                   title  video  vote_average  vote_count
# 0                          Inside Out 2  False         7.710        1288
# 1               Furiosa: A Mad Max Saga  False         7.700        1688
# 2     Kingdom of the Planet of the Apes  False         6.863        1291
# 3                 Bad Boys: Ride or Die  False         7.025         477
# 4                       Trigger Warning  False         5.779         240
# ...                                 ...    ...           ...         ...
# 1995                         Below Zero  False         6.384         889
# 1996                        True Spirit  False         6.961         205
# 1997                       Batman: Hush  False         7.179         843
# 1998                         La Llorona  False         6.436         319
# 1999                Strange Way of Life  False         6.487         238
#
# [2000 rows x 14 columns]

# %%
dropped_movies_df = movie_df.drop(columns=["adult", "backdrop_path", "poster_path", "video",])
dropped_movies_df
# Out:
#               genre_ids       id original_language  \
# 0     16, 10751, 12, 35  1022789                en
# 1           28, 12, 878   786892                en
# 2           878, 12, 28   653346                en
# 3        28, 80, 53, 35   573435                en
# 4            28, 80, 53   704673                en
# ...                 ...      ...               ...
# 1995         28, 80, 53   587996                es
# 1996         12, 18, 36   739986                en
# 1997   28, 16, 80, 9648   537056                en
# 1998         53, 27, 18   617708                es
# 1999      18, 37, 10749   963765                es
#
#                          original_title  \
# 0                          Inside Out 2
# 1               Furiosa: A Mad Max Saga
# 2     Kingdom of the Planet of the Apes
# 3                 Bad Boys: Ride or Die
# 4                       Trigger Warning
# ...                                 ...
# 1995                           Bajocero
# 1996                        True Spirit
# 1997                       Batman: Hush
# 1998                         La Llorona
# 1999              Extraña forma de vida
#
#                                                overview  popularity  \
# 0     Teenager Riley's mind headquarters is undergoi...    4128.506
# 1     As the world fell, young Furiosa is snatched f...    4115.719
# 2     Several generations in the future following Ca...    1777.192
# 3     After their late former Captain is framed, Low...    1329.004
# 4     A Special Forces commando uncovers a dangerous...    1205.913
# ...                                                 ...         ...
# 1995  When a prisoner transfer van is attacked, the ...      15.647
# 1996  When the tenacious young sailor Jessica Watson...      29.236
# 1997  A mysterious new villain known only as Hush us...      16.890
# 1998  Accused of the genocide of Mayan people, retir...      16.641
# 1999  After 25 years, an ex hired gun visits his old...      17.678
#
#      release_date                              title  vote_average  vote_count
# 0      2024-06-11                       Inside Out 2         7.710        1288
# 1      2024-05-22            Furiosa: A Mad Max Saga         7.700        1688
# 2      2024-05-08  Kingdom of the Planet of the Apes         6.863        1291
# 3      2024-06-05              Bad Boys: Ride or Die         7.025         477
# 4      2024-06-20                    Trigger Warning         5.779         240
# ...           ...                                ...           ...         ...
# 1995   2021-01-29                         Below Zero         6.384         889
# 1996   2023-01-26                        True Spirit         6.961         205
# 1997   2019-07-19                       Batman: Hush         7.179         843
# 1998   2019-07-25                         La Llorona         6.436         319
# 1999   2023-05-26                Strange Way of Life         6.487         238
#
# [2000 rows x 10 columns]

# %%
sorted_vote_movies_df = dropped_movies_df.sort_values("vote_average", ascending=False)
sorted_vote_movies_df
# Out:
#              genre_ids       id original_language             original_title  \
# 679              10749   719457                ko                    옆집 소녀 4
# 684          18, 10749  1135869                id     Kelas Bintang - Salome
# 314              10749   766836                ko              아들의 여친 아빠의 여친
# 1288                18  1241750                tl                  Mapanukso
# 567   27, 18, 9648, 53  1020830                mn                  Aberrance
# ...                ...      ...               ...                        ...
# 1886                    1261287                pt              Constantine 2
# 667             27, 18  1134562                en  The Woman Under the Stage
# 670        28, 878, 12   365177                en                Borderlands
# 677         28, 80, 53   755679                en             Fast X: Part 2
# 621              10749   689160                ko                   맛있는 과외누나
#
#                                                overview  popularity  \
# 679   Even Dong-ho, who got his dream home, went to ...      35.727
# 684   Kelas Bintang is back with this pack of drama ...      48.501
# 314   Dong-gook, who is thinking of remarrying, intr...      87.841
# 1288  Story about a group of five macho dancers navi...      21.699
# 567   An estranged couple takes a retreat in the woo...      49.374
# ...                                                 ...         ...
# 1886                                                         19.759
# 667   A young woman discovers just how far she will ...      42.870
# 670   After returning to her home planet Pandora, in...      46.824
# 677          The eleventh installment in The Fast Saga.      42.755
# 621   Bong-soo receives a love tutor from Hope to es...      48.013
#
#      release_date                                 title  vote_average  \
# 679    2020-07-03                  The Girl Next Door 4          10.0
# 684    2023-05-13                                Salome          10.0
# 314    2020-11-13  Son's Girlfriend, Daddy's Girlfriend          10.0
# 1288   2024-03-15                             Mapanukso          10.0
# 567    2022-08-01                             Aberrance          10.0
# ...           ...                                   ...           ...
# 1886   2024-09-20                         Constantine 2           0.0
# 667    2023-08-03             The Woman Under the Stage           0.0
# 670    2024-08-07                           Borderlands           0.0
# 677    2026-06-22                        Fast X: Part 2           0.0
# 621    2020-04-03                       Delicious Tutor           0.0
#
#       vote_count
# 679            1
# 684            1
# 314            1
# 1288           1
# 567            1
# ...          ...
# 1886           0
# 667            0
# 670            0
# 677            0
# 621            0
#
# [2000 rows x 10 columns]

# %%
vote_count_movies_df = sorted_vote_movies_df.loc[sorted_vote_movies_df["vote_count"] > 1000]
vote_count_movies_df
# Out:
#             genre_ids      id original_language  \
# 200        35, 53, 18  496243                ko
# 103   16, 28, 12, 878  569094                en
# 971                18  637920                tr
# 619         10749, 18  527641                en
# 551         18, 10749  447362                en
# ...               ...     ...               ...
# 1279     53, 9648, 18  452832                en
# 1451         27, 9648  465086                en
# 976            27, 53  632727                en
# 517            27, 53  980078                en
# 783               878  433249                en
#
#                            original_title  \
# 200                                   기생충
# 103   Spider-Man: Across the Spider-Verse
# 971                   7. Koğuştaki Mucize
# 619                       Five Feet Apart
# 551                        Life in a Year
# ...                                   ...
# 1279                             Serenity
# 1451                           The Grudge
# 976               Texas Chainsaw Massacre
# 517      Winnie the Pooh: Blood and Honey
# 783                                    IO
#
#                                                overview  popularity  \
# 200   All unemployed, Ki-taek's family takes peculia...      86.639
# 103   After reuniting with Gwen Stacy, Brooklyn’s fu...     176.846
# 971   Separated from his daughter, a father with an ...      34.256
# 619   Seventeen-year-old Stella spends most of her t...      41.779
# 551   A 17 year old finds out that his girlfriend is...      53.193
# ...                                                 ...         ...
# 1279  The quiet life of Baker Dill, a fishing boat c...      29.511
# 1451  After a young mother murders her family in her...      16.911
# 976   After nearly 50 years of hiding, Leatherface r...      32.992
# 517   Christopher Robin is headed off to college and...      51.232
# 783   As a young scientist searches for a way to sav...      40.690
#
#      release_date                                title  vote_average  \
# 200    2019-05-30                             Parasite         8.500
# 103    2023-05-31  Spider-Man: Across the Spider-Verse         8.365
# 971    2019-10-10                Miracle in Cell No. 7         8.300
# 619    2019-03-14                      Five Feet Apart         8.268
# 551    2020-11-27                       Life in a Year         8.261
# ...           ...                                  ...           ...
# 1279   2019-01-24                             Serenity         5.500
# 1451   2019-12-31                           The Grudge         5.500
# 976    2022-02-18              Texas Chainsaw Massacre         5.214
# 517    2023-01-27     Winnie the Pooh: Blood and Honey         5.121
# 783    2019-01-18                                   IO         4.927
#
#       vote_count
# 200        17702
# 103         6427
# 971         4327
# 619         5475
# 551         1793
# ...          ...
# 1279        1488
# 1451        1157
# 976         1374
# 517         1252
# 783         1330
#
# [512 rows x 10 columns]

# %%
top_500_movies_df = pd.DataFrame(vote_count_movies_df.head(500), columns=vote_count_movies_df.columns).reset_index()
top_500_movies_df
# Out:
#      index         genre_ids      id original_language  \
# 0      200        35, 53, 18  496243                ko
# 1      103   16, 28, 12, 878  569094                en
# 2      971                18  637920                tr
# 3      619         10749, 18  527641                en
# 4      551         18, 10749  447362                en
# ..     ...               ...     ...               ...
# 495   1235        28, 53, 80  539885                en
# 496    868    28, 80, 53, 35  438650                en
# 497   1869  27, 14, 12, 9648  539537                en
# 498   1144      27, 53, 9648  502416                en
# 499   1755           878, 53  615469                en
#
#                           original_title  \
# 0                                    기생충
# 1    Spider-Man: Across the Spider-Verse
# 2                    7. Koğuştaki Mucize
# 3                        Five Feet Apart
# 4                         Life in a Year
# ..                                   ...
# 495                                  Ava
# 496                         Cold Pursuit
# 497                       Fantasy Island
# 498                                   Ma
# 499                           Spiderhead
#
#                                               overview  popularity  \
# 0    All unemployed, Ki-taek's family takes peculia...      86.639
# 1    After reuniting with Gwen Stacy, Brooklyn’s fu...     176.846
# 2    Separated from his daughter, a father with an ...      34.256
# 3    Seventeen-year-old Stella spends most of her t...      41.779
# 4    A 17 year old finds out that his girlfriend is...      53.193
# ..                                                 ...         ...
# 495  A black ops assassin is forced to fight for he...      27.375
# 496  The quiet family life of Nels Coxman, a snowpl...      41.473
# 497  A group of contest winners arrive at an island...      24.285
# 498  Sue Ann is a loner who keeps to herself in her...      37.100
# 499  A prisoner in a state-of-the-art penitentiary ...      29.211
#
#     release_date                                title  vote_average  \
# 0     2019-05-30                             Parasite         8.500
# 1     2023-05-31  Spider-Man: Across the Spider-Verse         8.365
# 2     2019-10-10                Miracle in Cell No. 7         8.300
# 3     2019-03-14                      Five Feet Apart         8.268
# 4     2020-11-27                       Life in a Year         8.261
# ..           ...                                  ...           ...
# 495   2020-07-02                                  Ava         5.820
# 496   2019-02-07                         Cold Pursuit         5.810
# 497   2020-02-12                       Fantasy Island         5.809
# 498   2019-05-29                                   Ma         5.800
# 499   2022-06-17                           Spiderhead         5.798
#
#      vote_count
# 0         17702
# 1          6427
# 2          4327
# 3          5475
# 4          1793
# ..          ...
# 495        2504
# 496        2502
# 497        2378
# 498        2128
# 499        1474
#
# [500 rows x 11 columns]

# %%
top_500_movies_df["original_language"].value_counts()
# Out:
# original_language
# en    458
# ja     10
# fr      9
# ko      5
# es      5
# pl      3
# de      2
# no      2
# it      2
# tr      1
# te      1
# da      1
# fi      1
# Name: count, dtype: int64

# %%
cleaned_top_500_movies_df = top_500_movies_df[["id", "original_title", "title", "genre_ids", "original_language","overview", "release_date", "popularity", "vote_average", "vote_count"]]
cleaned_top_500_movies_df
# Out:
#          id                       original_title  \
# 0    496243                                  기생충
# 1    569094  Spider-Man: Across the Spider-Verse
# 2    637920                  7. Koğuştaki Mucize
# 3    527641                      Five Feet Apart
# 4    447362                       Life in a Year
# ..      ...                                  ...
# 495  539885                                  Ava
# 496  438650                         Cold Pursuit
# 497  539537                       Fantasy Island
# 498  502416                                   Ma
# 499  615469                           Spiderhead
#
#                                    title         genre_ids original_language  \
# 0                               Parasite        35, 53, 18                ko
# 1    Spider-Man: Across the Spider-Verse   16, 28, 12, 878                en
# 2                  Miracle in Cell No. 7                18                tr
# 3                        Five Feet Apart         10749, 18                en
# 4                         Life in a Year         18, 10749                en
# ..                                   ...               ...               ...
# 495                                  Ava        28, 53, 80                en
# 496                         Cold Pursuit    28, 80, 53, 35                en
# 497                       Fantasy Island  27, 14, 12, 9648                en
# 498                                   Ma      27, 53, 9648                en
# 499                           Spiderhead           878, 53                en
#
#                                               overview release_date  \
# 0    All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 1    After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31
# 2    Separated from his daughter, a father with an ...   2019-10-10
# 3    Seventeen-year-old Stella spends most of her t...   2019-03-14
# 4    A 17 year old finds out that his girlfriend is...   2020-11-27
# ..                                                 ...          ...
# 495  A black ops assassin is forced to fight for he...   2020-07-02
# 496  The quiet family life of Nels Coxman, a snowpl...   2019-02-07
# 497  A group of contest winners arrive at an island...   2020-02-12
# 498  Sue Ann is a loner who keeps to herself in her...   2019-05-29
# 499  A prisoner in a state-of-the-art penitentiary ...   2022-06-17
#
#      popularity  vote_average  vote_count
# 0        86.639         8.500       17702
# 1       176.846         8.365        6427
# 2        34.256         8.300        4327
# 3        41.779         8.268        5475
# 4        53.193         8.261        1793
# ..          ...           ...         ...
# 495      27.375         5.820        2504
# 496      41.473         5.810        2502
# 497      24.285         5.809        2378
# 498      37.100         5.800        2128
# 499      29.211         5.798        1474
#
# [500 rows x 10 columns]

# %%
cleaned_top_500_movies_df = cleaned_top_500_movies_df.rename(columns=str.title)

# %%
final_top_500_movies_df = cleaned_top_500_movies_df.drop(columns="Genre_Ids").rename(columns={"Id": "Movie_Id", "Original_Language": "Language_Id"})
final_top_500_movies_df
# Out:
#      Movie_Id                       Original_Title  \
# 0      496243                                  기생충
# 1      569094  Spider-Man: Across the Spider-Verse
# 2      637920                  7. Koğuştaki Mucize
# 3      527641                      Five Feet Apart
# 4      447362                       Life in a Year
# ..        ...                                  ...
# 495    539885                                  Ava
# 496    438650                         Cold Pursuit
# 497    539537                       Fantasy Island
# 498    502416                                   Ma
# 499    615469                           Spiderhead
#
#                                    Title Language_Id  \
# 0                               Parasite          ko
# 1    Spider-Man: Across the Spider-Verse          en
# 2                  Miracle in Cell No. 7          tr
# 3                        Five Feet Apart          en
# 4                         Life in a Year          en
# ..                                   ...         ...
# 495                                  Ava          en
# 496                         Cold Pursuit          en
# 497                       Fantasy Island          en
# 498                                   Ma          en
# 499                           Spiderhead          en
#
#                                               Overview Release_Date  \
# 0    All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 1    After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31
# 2    Separated from his daughter, a father with an ...   2019-10-10
# 3    Seventeen-year-old Stella spends most of her t...   2019-03-14
# 4    A 17 year old finds out that his girlfriend is...   2020-11-27
# ..                                                 ...          ...
# 495  A black ops assassin is forced to fight for he...   2020-07-02
# 496  The quiet family life of Nels Coxman, a snowpl...   2019-02-07
# 497  A group of contest winners arrive at an island...   2020-02-12
# 498  Sue Ann is a loner who keeps to herself in her...   2019-05-29
# 499  A prisoner in a state-of-the-art penitentiary ...   2022-06-17
#
#      Popularity  Vote_Average  Vote_Count
# 0        86.639         8.500       17702
# 1       176.846         8.365        6427
# 2        34.256         8.300        4327
# 3        41.779         8.268        5475
# 4        53.193         8.261        1793
# ..          ...           ...         ...
# 495      27.375         5.820        2504
# 496      41.473         5.810        2502
# 497      24.285         5.809        2378
# 498      37.100         5.800        2128
# 499      29.211         5.798        1474
#
# [500 rows x 9 columns]

# %%
final_top_500_movies_df.to_csv("../Outputs/movies.csv", encoding='utf8', index=False)

# %%
movie_genre_df = pd.DataFrame({"Movie_id": cleaned_top_500_movies_df["Id"],
                               "Genre_id": cleaned_top_500_movies_df["Genre_Ids"]})
movie_genre_df
# Out:
#      Movie_id          Genre_id
# 0      496243        35, 53, 18
# 1      569094   16, 28, 12, 878
# 2      637920                18
# 3      527641         10749, 18
# 4      447362         18, 10749
# ..        ...               ...
# 495    539885        28, 53, 80
# 496    438650    28, 80, 53, 35
# 497    539537  27, 14, 12, 9648
# 498    502416      27, 53, 9648
# 499    615469           878, 53
#
# [500 rows x 2 columns]

# %%
split_df = movie_genre_df.assign(Genre_id=movie_genre_df['Genre_id'].str.split(',')).explode('Genre_id').reset_index()

cleaned_movie_genre_df = split_df[["Movie_id", "Genre_id"]].rename(columns=str.title)
cleaned_movie_genre_df
# Out:
#       Movie_Id Genre_Id
# 0       496243       35
# 1       496243       53
# 2       496243       18
# 3       569094       16
# 4       569094       28
# ...        ...      ...
# 1422    502416       27
# 1423    502416       53
# 1424    502416     9648
# 1425    615469      878
# 1426    615469       53
#
# [1427 rows x 2 columns]

# %%
cleaned_movie_genre_df["Genre_Id"] = cleaned_movie_genre_df["Genre_Id"].apply(lambda x: x.replace(' ',''))

# %%
cleaned_movie_genre_df.to_csv("../Outputs/movie_genre.csv",  encoding='utf8', index=False)

# %%
import sqlite3
from sqlalchemy import create_engine

# Connect to PostgreSQL
pg_engine = create_engine('postgresql://postgres:postgres@localhost:5432/Movies_db')

# Connect to SQLite
sqlite_conn = sqlite3.connect('movies.sqlite')

# Get list of tables
tables = pd.read_sql("SELECT table_name FROM information_schema.tables WHERE table_schema='public'", pg_engine)

# Iterate over tables and copy data
for table in tables['table_name']:
    print(f"Copying table {table}")
    df = pd.read_sql_table(table, pg_engine)
    df.to_sql(table, sqlite_conn, if_exists='replace', index=False)

sqlite_conn.close()
pg_engine.dispose()
# Out:
# Copying table language
# Copying table movie
# Copying table genre
# Copying table movie_genre

# %%
import sqlalchemy
from sqlalchemy import create_engine, text
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
# Create engine using the `movies.sqlite` database file
engine = create_engine("sqlite:///movies.sqlite")

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# Use the Base class to reflect the database tables
Base.prepare(autoload_with=engine)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['genre', 'movie', 'language']

# %%
Movie = Base.classes.movie

# %%
for column in Movie.__table__.columns:
    print(f"{column.name} ({column.type}), Primary Key: {column.primary_key}")
# Out:
# movie_id (INTEGER), Primary Key: True
# original_title (TEXT), Primary Key: False
# title (TEXT), Primary Key: False
# language_id (TEXT), Primary Key: False
# overview (TEXT), Primary Key: False
# release_date (TIMESTAMP), Primary Key: False
# popularity (REAL), Primary Key: False
# vote_average (REAL), Primary Key: False
# vote_count (INTEGER), Primary Key: False

# %%
session = Session(engine)

    # Query all movies
results = session.query(Movie.movie_id, Movie.title, Movie.release_date, Movie.popularity, Movie.vote_average, Movie.vote_count).all()

for result in results:
    print(result)
# Out:
# (38700, 'Bad Boys for Life', datetime.datetime(2020, 1, 15, 0, 0), 416.283, 7.132, 7999)
# (49046, 'All Quiet on the Western Front', datetime.datetime(2022, 10, 7, 0, 0), 64.477, 7.738, 3665)
# (76600, 'Avatar: The Way of Water', datetime.datetime(2022, 12, 14, 0, 0), 166.333, 7.623, 11437)
# (166428, 'How to Train Your Dragon: The Hidden World', datetime.datetime(2019, 1, 3, 0, 0), 84.722, 7.752, 6184)
# (181812, 'Star Wars: The Rise of Skywalker', datetime.datetime(2019, 12, 18, 0, 0), 66.939, 6.332, 9623)
# (280217, 'The Lego Movie 2: The Second Part', datetime.datetime(2019, 2, 6, 0, 0), 30.203, 6.688, 2117)
# (287947, 'Shazam!', datetime.datetime(2019, 3, 29, 0, 0), 81.14, 7.016, 9283)
# (290859, 'Terminator: Dark Fate', datetime.datetime(2019, 10, 23, 0, 0), 54.244, 6.454, 4925)
# (292011, 'Richard Jewell', datetime.datetime(2019, 12, 13, 0, 0), 32.442, 7.429, 2429)
# (298618, 'The Flash', datetime.datetime(2023, 6, 13, 0, 0), 213.474, 6.73, 3997)
# (299054, 'Expend4bles', datetime.datetime(2023, 9, 15, 0, 0), 133.736, 6.253, 1386)
# (299534, 'Avengers: Endgame', datetime.datetime(2019, 4, 24, 0, 0), 127.987, 8.254, 25044)
# (299537, 'Captain Marvel', datetime.datetime(2019, 3, 6, 0, 0), 182.141, 6.82, 15379)
# (301502, 'Blonde', datetime.datetime(2022, 9, 16, 0, 0), 31.962, 6.012, 1284)
# (301528, 'Toy Story 4', datetime.datetime(2019, 6, 19, 0, 0), 93.716, 7.501, 9545)
# (315162, 'Puss in Boots: The Last Wish', datetime.datetime(2022, 12, 7, 0, 0), 172.852, 8.234, 7375)
# (320288, 'Dark Phoenix', datetime.datetime(2019, 6, 5, 0, 0), 127.804, 5.98, 6319)
# (327331, 'The Dirt', datetime.datetime(2019, 3, 22, 0, 0), 37.009, 7.463, 1192)
# (329996, 'Dumbo', datetime.datetime(2019, 3, 27, 0, 0), 44.854, 6.627, 4233)
# (330457, 'Frozen II', datetime.datetime(2019, 11, 20, 0, 0), 87.35, 7.262, 9506)
# (331482, 'Little Women', datetime.datetime(2019, 12, 25, 0, 0), 42.589, 7.882, 6094)
# (335787, 'Uncharted', datetime.datetime(2022, 2, 10, 0, 0), 55.277, 6.955, 5720)
# (335977, 'Indiana Jones and the Dial of Destiny', datetime.datetime(2023, 6, 25, 0, 0), 88.084, 6.595, 3130)
# (337401, 'Mulan', datetime.datetime(2020, 9, 4, 0, 0), 50.559, 6.88, 6498)
# (337404, 'Cruella', datetime.datetime(2021, 5, 26, 0, 0), 77.296, 8.018, 9075)
# (338762, 'Bloodshot', datetime.datetime(2020, 3, 5, 0, 0), 36.279, 6.733, 4860)
# (338953, 'Fantastic Beasts: The Secrets of Dumbledore', datetime.datetime(2022, 4, 6, 0, 0), 62.392, 6.666, 4292)
# (338958, 'Disenchanted', datetime.datetime(2022, 11, 18, 0, 0), 37.28, 6.758, 1041)
# (338967, 'Zombieland: Double Tap', datetime.datetime(2019, 10, 9, 0, 0), 43.258, 6.936, 5516)
# (340102, 'The New Mutants', datetime.datetime(2020, 4, 2, 0, 0), 53.119, 6.109, 3308)
# (342470, 'All the Bright Places', datetime.datetime(2020, 2, 28, 0, 0), 26.239, 7.652, 2802)
# (346698, 'Barbie', datetime.datetime(2023, 7, 19, 0, 0), 229.389, 7.047, 8525)
# (347626, "He's All That", datetime.datetime(2021, 8, 27, 0, 0), 25.819, 6.556, 1324)
# (359410, 'Road House', datetime.datetime(2024, 3, 8, 0, 0), 258.827, 7.005, 1967)
# (359724, 'Ford v Ferrari', datetime.datetime(2019, 11, 13, 0, 0), 58.479, 8.004, 7649)
# (361743, 'Top Gun: Maverick', datetime.datetime(2022, 5, 21, 0, 0), 125.749, 8.215, 8748)
# (370172, 'No Time to Die', datetime.datetime(2021, 9, 29, 0, 0), 67.14, 7.38, 6022)
# (373571, 'Godzilla: King of the Monsters', datetime.datetime(2019, 5, 29, 0, 0), 75.596, 6.705, 5982)
# (379686, 'Space Jam: A New Legacy', datetime.datetime(2021, 7, 8, 0, 0), 43.141, 6.758, 3918)
# (384018, 'Fast & Furious Presents: Hobbs & Shaw', datetime.datetime(2019, 8, 1, 0, 0), 87.126, 6.865, 6998)
# (385103, 'Scoob!', datetime.datetime(2020, 7, 8, 0, 0), 24.897, 7.074, 1644)
# (385128, 'F9', datetime.datetime(2021, 5, 19, 0, 0), 60.156, 7.088, 7027)
# (385687, 'Fast X', datetime.datetime(2023, 5, 17, 0, 0), 317.402, 7.114, 5300)
# (398978, 'The Irishman', datetime.datetime(2019, 11, 1, 0, 0), 66.245, 7.606, 6610)
# (399361, 'Triple Frontier', datetime.datetime(2019, 3, 6, 0, 0), 34.513, 6.31, 3087)
# (399566, 'Godzilla vs. Kong', datetime.datetime(2021, 3, 24, 0, 0), 69.389, 7.613, 9769)
# (399579, 'Alita: Battle Angel', datetime.datetime(2019, 1, 31, 0, 0), 61.641, 7.233, 8903)
# (400160, 'The SpongeBob Movie: Sponge on the Run', datetime.datetime(2020, 8, 14, 0, 0), 66.709, 7.486, 2802)
# (406759, 'Moonfall', datetime.datetime(2022, 2, 3, 0, 0), 55.29, 6.333, 2993)
# (412117, 'The Secret Life of Pets 2', datetime.datetime(2019, 5, 24, 0, 0), 50.056, 6.962, 2938)
# (412656, 'Chaos Walking', datetime.datetime(2021, 2, 24, 0, 0), 43.101, 6.593, 2203)
# (413518, 'Pinocchio', datetime.datetime(2019, 12, 19, 0, 0), 22.931, 6.6, 1481)
# (414906, 'The Batman', datetime.datetime(2022, 3, 1, 0, 0), 219.542, 7.678, 9775)
# (416144, 'Hotel Mumbai', datetime.datetime(2019, 3, 14, 0, 0), 24.643, 7.543, 1491)
# (417384, 'Scary Stories to Tell in the Dark', datetime.datetime(2019, 8, 8, 0, 0), 30.507, 6.499, 2567)
# (420809, 'Maleficent: Mistress of Evil', datetime.datetime(2019, 10, 16, 0, 0), 45.202, 7.309, 5952)
# (420817, 'Aladdin', datetime.datetime(2019, 5, 22, 0, 0), 63.314, 7.109, 9810)
# (420818, 'The Lion King', datetime.datetime(2019, 7, 12, 0, 0), 95.88, 7.115, 9754)
# (420821, "Chip 'n Dale: Rescue Rangers", datetime.datetime(2022, 5, 20, 0, 0), 24.735, 7.004, 1161)
# (423108, 'The Conjuring: The Devil Made Me Do It', datetime.datetime(2021, 5, 25, 0, 0), 103.117, 7.447, 5731)
# (423204, 'Angel Has Fallen', datetime.datetime(2019, 8, 21, 0, 0), 41.188, 6.577, 3368)
# (425909, 'Ghostbusters: Afterlife', datetime.datetime(2021, 11, 18, 0, 0), 96.051, 7.399, 4425)
# (429617, 'Spider-Man: Far From Home', datetime.datetime(2019, 6, 28, 0, 0), 89.963, 7.429, 15282)
# (431580, 'Abominable', datetime.datetime(2019, 9, 19, 0, 0), 29.956, 7.476, 1978)
# (431693, 'Spies in Disguise', datetime.datetime(2019, 12, 4, 0, 0), 24.135, 7.594, 2722)
# (436270, 'Black Adam', datetime.datetime(2022, 10, 19, 0, 0), 96.128, 6.936, 6026)
# (436969, 'The Suicide Squad', datetime.datetime(2021, 7, 28, 0, 0), 89.688, 7.5, 8305)
# (438148, 'Minions: The Rise of Gru', datetime.datetime(2022, 6, 29, 0, 0), 170.784, 7.345, 3425)
# (438631, 'Dune', datetime.datetime(2021, 9, 15, 0, 0), 212.102, 7.783, 12052)
# (438650, 'Cold Pursuit', datetime.datetime(2019, 2, 7, 0, 0), 41.473, 5.81, 2502)
# (438695, 'Sing 2', datetime.datetime(2021, 12, 1, 0, 0), 98.683, 7.875, 4243)
# (440472, 'The Upside', datetime.datetime(2019, 1, 10, 0, 0), 37.747, 7.144, 1228)
# (441130, 'Wolfwalkers', datetime.datetime(2020, 10, 26, 0, 0), 24.182, 8.218, 1128)
# (443791, 'Underwater', datetime.datetime(2020, 1, 8, 0, 0), 27.106, 6.286, 3014)
# (445629, 'Fighting with My Family', datetime.datetime(2019, 2, 14, 0, 0), 20.693, 6.862, 1640)
# (446893, 'Trolls World Tour', datetime.datetime(2020, 3, 11, 0, 0), 52.927, 7.31, 2095)
# (447277, 'The Little Mermaid', datetime.datetime(2023, 5, 18, 0, 0), 121.558, 6.373, 2770)
# (447362, 'Life in a Year', datetime.datetime(2020, 11, 27, 0, 0), 53.193, 8.261, 1793)
# (447365, 'Guardians of the Galaxy Vol. 3', datetime.datetime(2023, 5, 3, 0, 0), 127.763, 8.0, 6406)
# (447404, 'Pokémon Detective Pikachu', datetime.datetime(2019, 5, 3, 0, 0), 39.465, 6.933, 6631)
# (448119, 'Dolittle', datetime.datetime(2020, 1, 2, 0, 0), 30.907, 6.613, 3546)
# (449562, 'The Hustle', datetime.datetime(2019, 5, 9, 0, 0), 30.258, 6.196, 2428)
# (450465, 'Glass', datetime.datetime(2019, 1, 16, 0, 0), 81.986, 6.678, 8228)
# (451048, 'Jungle Cruise', datetime.datetime(2021, 7, 28, 0, 0), 52.612, 7.379, 5527)
# (453395, 'Doctor Strange in the Multiverse of Madness', datetime.datetime(2022, 5, 4, 0, 0), 93.93, 7.3, 8749)
# (453405, 'Gemini Man', datetime.datetime(2019, 10, 2, 0, 0), 63.118, 6.297, 4978)
# (454626, 'Sonic the Hedgehog', datetime.datetime(2020, 2, 12, 0, 0), 61.65, 7.327, 9298)
# (454640, 'The Angry Birds Movie 2', datetime.datetime(2019, 8, 2, 0, 0), 42.985, 7.085, 1626)
# (455476, 'Knights of the Zodiac', datetime.datetime(2023, 4, 27, 0, 0), 55.165, 6.427, 1082)
# (457799, 'Extremely Wicked, Shockingly Evil and Vile', datetime.datetime(2019, 5, 2, 0, 0), 25.146, 7.014, 3256)
# (458156, 'John Wick: Chapter 3 - Parabellum', datetime.datetime(2019, 5, 15, 0, 0), 110.25, 7.444, 10308)
# (458220, 'Palmer', datetime.datetime(2021, 1, 28, 0, 0), 32.919, 8.137, 1524)
# (458305, 'Vivarium', datetime.datetime(2019, 9, 7, 0, 0), 40.237, 6.063, 2020)
# (458576, 'Monster Hunter', datetime.datetime(2020, 12, 3, 0, 0), 39.721, 6.594, 3219)
# (458723, 'Us', datetime.datetime(2019, 3, 14, 0, 0), 50.482, 6.97, 7147)
# (458897, "Charlie's Angels", datetime.datetime(2019, 11, 14, 0, 0), 31.706, 6.453, 2885)
# (459151, 'The Boss Baby: Family Business', datetime.datetime(2021, 7, 1, 0, 0), 72.255, 7.39, 2463)
# (459992, 'Long Shot', datetime.datetime(2019, 5, 2, 0, 0), 24.747, 6.735, 2594)
# (460458, 'Resident Evil: Welcome to Raccoon City', datetime.datetime(2021, 11, 24, 0, 0), 56.428, 6.0, 2359)
# (460465, 'Mortal Kombat', datetime.datetime(2021, 4, 7, 0, 0), 41.413, 7.045, 5689)
# (461130, 'Code 8', datetime.datetime(2019, 12, 6, 0, 0), 34.368, 6.262, 1900)
# (464052, 'Wonder Woman 1984', datetime.datetime(2020, 12, 16, 0, 0), 72.517, 6.441, 8233)
# (466272, 'Once Upon a Time... in Hollywood', datetime.datetime(2019, 7, 24, 0, 0), 51.326, 7.441, 13054)
# (466420, 'Killers of the Flower Moon', datetime.datetime(2023, 10, 18, 0, 0), 105.482, 7.479, 3001)
# (467244, 'The Zone of Interest', datetime.datetime(2023, 12, 15, 0, 0), 81.263, 7.182, 1431)
# (471498, 'Oxygen', datetime.datetime(2021, 5, 12, 0, 0), 22.892, 6.614, 1342)
# (471506, 'Greta', datetime.datetime(2019, 2, 28, 0, 0), 28.479, 6.6, 1285)
# (473033, 'Uncut Gems', datetime.datetime(2019, 8, 30, 0, 0), 62.128, 7.153, 4575)
# (474350, 'It Chapter Two', datetime.datetime(2019, 9, 4, 0, 0), 106.824, 6.844, 8484)
# (474764, 'The Lodge', datetime.datetime(2020, 1, 16, 0, 0), 26.465, 6.131, 1201)
# (475557, 'Joker', datetime.datetime(2019, 10, 1, 0, 0), 172.697, 8.16, 24817)
# (476669, "The King's Man", datetime.datetime(2021, 12, 22, 0, 0), 64.897, 6.771, 4324)
# (479455, 'Men in Black: International', datetime.datetime(2019, 6, 12, 0, 0), 31.21, 5.917, 4747)
# (481084, 'The Addams Family', datetime.datetime(2019, 10, 10, 0, 0), 36.597, 6.621, 2239)
# (481848, 'The Call of the Wild', datetime.datetime(2020, 2, 19, 0, 0), 35.444, 7.6, 3598)
# (482321, "Ron's Gone Wrong", datetime.datetime(2021, 10, 14, 0, 0), 28.479, 7.917, 1791)
# (482373, "Don't Breathe 2", datetime.datetime(2021, 8, 12, 0, 0), 43.589, 7.1, 2444)
# (483906, 'Polar', datetime.datetime(2019, 1, 25, 0, 0), 30.99, 6.281, 2127)
# (484468, "The Wolf's Call", datetime.datetime(2019, 2, 20, 0, 0), 29.825, 7.552, 1924)
# (484641, 'Anna', datetime.datetime(2019, 6, 19, 0, 0), 49.222, 6.718, 2615)
# (484718, 'Coming 2 America', datetime.datetime(2021, 3, 4, 0, 0), 51.842, 6.419, 2152)
# (486589, 'Red Shoes and the Seven Dwarfs', datetime.datetime(2019, 7, 25, 0, 0), 35.787, 7.7, 1052)
# (487297, 'What Men Want', datetime.datetime(2019, 2, 8, 0, 0), 39.082, 6.176, 1403)
# (491480, 'The Boy Who Harnessed the Wind', datetime.datetime(2019, 2, 14, 0, 0), 28.936, 7.914, 1616)
# (492188, 'Marriage Story', datetime.datetime(2019, 9, 28, 0, 0), 45.136, 7.744, 6776)
# (493529, 'Dungeons & Dragons: Honor Among Thieves', datetime.datetime(2023, 3, 23, 0, 0), 60.572, 7.377, 3238)
# (495764, 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)', datetime.datetime(2020, 2, 5, 0, 0), 58.098, 6.927, 10044)
# (496243, 'Parasite', datetime.datetime(2019, 5, 30, 0, 0), 86.639, 8.5, 17702)
# (497582, 'Enola Holmes', datetime.datetime(2020, 9, 23, 0, 0), 36.495, 7.284, 5875)
# (497698, 'Black Widow', datetime.datetime(2021, 7, 7, 0, 0), 103.638, 7.254, 9900)
# (497828, 'Triangle of Sadness', datetime.datetime(2022, 9, 18, 0, 0), 27.629, 7.09, 2030)
# (499701, 'Dora and the Lost City of Gold', datetime.datetime(2019, 8, 8, 0, 0), 32.365, 6.654, 1659)
# (499932, 'The Devil All the Time', datetime.datetime(2020, 9, 11, 0, 0), 26.274, 7.208, 3232)
# (500682, 'The Highwaymen', datetime.datetime(2019, 3, 15, 0, 0), 35.931, 6.752, 1961)
# (501170, 'Doctor Sleep', datetime.datetime(2019, 10, 30, 0, 0), 47.474, 7.152, 4263)
# (501929, 'The Mitchells vs. the Machines', datetime.datetime(2021, 4, 22, 0, 0), 36.641, 7.915, 2840)
# (502033, 'Sound of Metal', datetime.datetime(2020, 11, 20, 0, 0), 18.118, 7.7, 2437)
# (502356, 'The Super Mario Bros. Movie', datetime.datetime(2023, 4, 5, 0, 0), 211.716, 7.674, 8592)
# (502416, 'Ma', datetime.datetime(2019, 5, 29, 0, 0), 37.1, 5.8, 2128)
# (503736, 'Army of the Dead', datetime.datetime(2021, 5, 14, 0, 0), 24.668, 6.242, 3881)
# (503919, 'The Lighthouse', datetime.datetime(2019, 10, 18, 0, 0), 37.62, 7.5, 4653)
# (504562, 'Motherless Brooklyn', datetime.datetime(2019, 10, 31, 0, 0), 19.704, 6.703, 1402)
# (504608, 'Rocketman', datetime.datetime(2019, 5, 17, 0, 0), 38.62, 7.328, 4528)
# (504949, 'The King', datetime.datetime(2019, 10, 11, 0, 0), 42.296, 7.15, 3127)
# (505026, 'Death on the Nile', datetime.datetime(2022, 2, 9, 0, 0), 34.252, 6.434, 3522)
# (505600, 'Booksmart', datetime.datetime(2019, 5, 24, 0, 0), 46.449, 7.035, 2552)
# (505642, 'Black Panther: Wakanda Forever', datetime.datetime(2022, 11, 9, 0, 0), 107.957, 7.12, 6228)
# (505948, 'I Am Mother', datetime.datetime(2019, 6, 7, 0, 0), 74.398, 6.691, 2479)
# (506574, 'Descendants 3', datetime.datetime(2019, 8, 2, 0, 0), 59.082, 7.7, 1445)
# (507086, 'Jurassic World Dominion', datetime.datetime(2022, 6, 1, 0, 0), 93.1, 6.714, 5835)
# (507089, "Five Nights at Freddy's", datetime.datetime(2023, 10, 25, 0, 0), 124.302, 7.63, 3725)
# (508439, 'Onward', datetime.datetime(2020, 2, 29, 0, 0), 37.675, 7.694, 5988)
# (508442, 'Soul', datetime.datetime(2020, 12, 25, 0, 0), 84.51, 8.133, 10158)
# (508763, "A Dog's Way Home", datetime.datetime(2019, 1, 10, 0, 0), 25.514, 7.348, 1072)
# (508883, 'The Boy and the Heron', datetime.datetime(2023, 7, 14, 0, 0), 235.278, 7.5, 1363)
# (508943, 'Luca', datetime.datetime(2021, 6, 17, 0, 0), 78.755, 7.828, 8144)
# (508947, 'Turning Red', datetime.datetime(2022, 3, 10, 0, 0), 193.13, 7.4, 5050)
# (508965, 'Klaus', datetime.datetime(2019, 11, 8, 0, 0), 25.094, 8.247, 3895)
# (509967, '6 Underground', datetime.datetime(2019, 12, 10, 0, 0), 40.391, 6.345, 4608)
# (511987, 'Crawl', datetime.datetime(2019, 7, 11, 0, 0), 25.733, 6.309, 3018)
# (512195, 'Red Notice', datetime.datetime(2021, 11, 4, 0, 0), 57.656, 6.775, 5584)
# (512196, 'Happy Death Day 2U', datetime.datetime(2019, 2, 13, 0, 0), 25.083, 6.305, 3287)
# (512200, 'Jumanji: The Next Level', datetime.datetime(2019, 12, 4, 0, 0), 51.189, 6.909, 8401)
# (512895, 'Lady and the Tramp', datetime.datetime(2019, 11, 12, 0, 0), 23.739, 7.23, 1506)
# (513310, 'Boss Level', datetime.datetime(2021, 2, 19, 0, 0), 38.037, 6.885, 1520)
# (514439, 'Breakthrough', datetime.datetime(2019, 4, 10, 0, 0), 21.315, 7.618, 1039)
# (514847, 'The Hunt', datetime.datetime(2020, 3, 11, 0, 0), 69.121, 6.649, 3067)
# (514999, 'Murder Mystery', datetime.datetime(2019, 5, 25, 0, 0), 31.455, 6.277, 4323)
# (515001, 'Jojo Rabbit', datetime.datetime(2019, 10, 18, 0, 0), 50.662, 8.024, 9263)
# (515195, 'Yesterday', datetime.datetime(2019, 6, 26, 0, 0), 37.008, 6.705, 3790)
# (516329, 'Antlers', datetime.datetime(2021, 10, 28, 0, 0), 28.249, 6.25, 1054)
# (516486, 'Greyhound', datetime.datetime(2020, 7, 9, 0, 0), 44.83, 7.407, 2796)
# (517116, 'Haunt', datetime.datetime(2019, 9, 13, 0, 0), 33.987, 6.692, 1149)
# (520763, 'A Quiet Place Part II', datetime.datetime(2021, 5, 21, 0, 0), 272.567, 7.498, 6180)
# (521029, 'Annabelle Comes Home', datetime.datetime(2019, 6, 26, 0, 0), 56.41, 6.419, 3380)
# (521777, 'Good Boys', datetime.datetime(2019, 8, 14, 0, 0), 19.982, 6.855, 1792)
# (522162, 'Midway', datetime.datetime(2019, 11, 6, 0, 0), 36.547, 7.138, 2400)
# (522241, 'The Courier', datetime.datetime(2020, 1, 24, 0, 0), 21.37, 7.043, 1079)
# (522402, 'Finch', datetime.datetime(2021, 11, 4, 0, 0), 33.689, 7.893, 3354)
# (522518, "A Dog's Journey", datetime.datetime(2019, 5, 3, 0, 0), 36.471, 8.052, 1436)
# (522627, 'The Gentlemen', datetime.datetime(2020, 1, 1, 0, 0), 48.548, 7.681, 5571)
# (522681, 'Escape Room', datetime.datetime(2019, 1, 3, 0, 0), 30.564, 6.539, 4541)
# (522924, 'The Art of Racing in the Rain', datetime.datetime(2019, 8, 8, 0, 0), 28.425, 8.206, 1434)
# (522931, "Hitman's Wife's Bodyguard", datetime.datetime(2021, 6, 14, 0, 0), 29.343, 6.7, 2175)
# (522938, 'Rambo: Last Blood', datetime.datetime(2019, 9, 19, 0, 0), 47.983, 6.525, 3750)
# (524047, 'Greenland', datetime.datetime(2020, 7, 29, 0, 0), 42.575, 7.138, 4348)
# (524434, 'Eternals', datetime.datetime(2021, 11, 3, 0, 0), 68.288, 6.876, 8013)
# (526896, 'Morbius', datetime.datetime(2022, 3, 30, 0, 0), 118.492, 6.037, 4149)
# (527261, 'The Silence', datetime.datetime(2019, 5, 16, 0, 0), 35.016, 6.024, 1496)
# (527641, 'Five Feet Apart', datetime.datetime(2019, 3, 14, 0, 0), 41.779, 8.268, 5475)
# (527774, 'Raya and the Last Dragon', datetime.datetime(2021, 3, 3, 0, 0), 82.762, 7.858, 6624)
# (529203, 'The Croods: A New Age', datetime.datetime(2020, 11, 25, 0, 0), 76.918, 7.49, 3721)
# (530382, 'In the Shadow of the Moon', datetime.datetime(2019, 9, 27, 0, 0), 22.138, 6.162, 1362)
# (530385, 'Midsommar', datetime.datetime(2019, 7, 3, 0, 0), 63.788, 7.2, 6819)
# (530915, '1917', datetime.datetime(2019, 12, 25, 0, 0), 35.995, 7.994, 12047)
# (531219, "Roald Dahl's The Witches", datetime.datetime(2020, 10, 26, 0, 0), 43.113, 6.377, 2733)
# (531309, 'Brightburn', datetime.datetime(2019, 5, 9, 0, 0), 66.173, 6.129, 3038)
# (531428, 'Portrait of a Lady on Fire', datetime.datetime(2019, 9, 18, 0, 0), 39.637, 8.128, 2442)
# (532639, 'Pinocchio', datetime.datetime(2022, 9, 7, 0, 0), 31.033, 6.372, 1537)
# (533642, "Child's Play", datetime.datetime(2019, 6, 19, 0, 0), 29.67, 5.967, 1838)
# (535292, '21 Bridges', datetime.datetime(2019, 10, 24, 0, 0), 28.658, 6.778, 1893)
# (535544, 'Downton Abbey', datetime.datetime(2019, 9, 12, 0, 0), 25.193, 7.141, 1094)
# (536437, 'Hypnotic', datetime.datetime(2023, 5, 11, 0, 0), 40.701, 6.243, 1110)
# (536554, 'M3GAN', datetime.datetime(2022, 12, 28, 0, 0), 54.813, 7.096, 3797)
# (537915, 'After', datetime.datetime(2019, 4, 11, 0, 0), 96.522, 7.129, 8091)
# (539537, 'Fantasy Island', datetime.datetime(2020, 2, 12, 0, 0), 24.285, 5.809, 2378)
# (539681, 'DC League of Super-Pets', datetime.datetime(2022, 7, 27, 0, 0), 34.504, 7.269, 1486)
# (539885, 'Ava', datetime.datetime(2020, 7, 2, 0, 0), 27.375, 5.82, 2504)
# (540901, 'Hustlers', datetime.datetime(2019, 9, 12, 0, 0), 68.606, 6.479, 2862)
# (542178, 'The French Dispatch', datetime.datetime(2021, 10, 21, 0, 0), 24.276, 7.057, 2472)
# (544401, 'Cherry', datetime.datetime(2021, 2, 26, 0, 0), 26.271, 7.346, 1211)
# (545609, 'Extraction', datetime.datetime(2020, 4, 24, 0, 0), 58.517, 7.332, 5892)
# (545611, 'Everything Everywhere All at Once', datetime.datetime(2022, 3, 24, 0, 0), 61.429, 7.784, 6170)
# (546121, 'Run', datetime.datetime(2020, 11, 20, 0, 0), 28.936, 7.254, 2467)
# (546554, 'Knives Out', datetime.datetime(2019, 11, 27, 0, 0), 51.032, 7.848, 11986)
# (547016, 'The Old Guard', datetime.datetime(2020, 7, 10, 0, 0), 22.863, 7.1, 4034)
# (547565, 'The Night House', datetime.datetime(2021, 7, 15, 0, 0), 22.25, 6.604, 1078)
# (548473, 'Color Out of Space', datetime.datetime(2019, 9, 7, 0, 0), 19.203, 6.017, 1392)
# (549053, 'Last Christmas', datetime.datetime(2019, 11, 7, 0, 0), 34.916, 7.241, 2285)
# (550205, 'Wish Dragon', datetime.datetime(2021, 1, 15, 0, 0), 44.222, 7.909, 1284)
# (550988, 'Free Guy', datetime.datetime(2021, 8, 11, 0, 0), 84.596, 7.507, 8408)
# (551804, 'Freaky', datetime.datetime(2020, 11, 12, 0, 0), 29.741, 6.574, 1562)
# (552178, 'Dark Waters', datetime.datetime(2019, 11, 22, 0, 0), 35.433, 7.524, 2066)
# (552688, 'The Mother', datetime.datetime(2023, 5, 4, 0, 0), 60.471, 6.664, 1192)
# (553604, 'Honest Thief', datetime.datetime(2020, 9, 3, 0, 0), 40.037, 6.501, 1669)
# (555604, "Guillermo del Toro's Pinocchio", datetime.datetime(2022, 10, 22, 0, 0), 41.483, 8.112, 2791)
# (556574, 'Hamilton', datetime.datetime(2020, 7, 3, 0, 0), 38.18, 8.197, 1346)
# (556678, 'Emma.', datetime.datetime(2020, 2, 13, 0, 0), 40.755, 7.046, 1661)
# (556694, 'Three Thousand Years of Longing', datetime.datetime(2022, 8, 24, 0, 0), 28.229, 6.887, 1256)
# (556984, 'The Trial of the Chicago 7', datetime.datetime(2020, 9, 25, 0, 0), 25.672, 7.706, 2952)
# (559969, 'El Camino: A Breaking Bad Movie', datetime.datetime(2019, 10, 11, 0, 0), 40.292, 6.956, 4738)
# (560050, 'Over the Moon', datetime.datetime(2020, 10, 16, 0, 0), 21.708, 7.213, 1264)
# (560057, 'The Sea Beast', datetime.datetime(2022, 6, 24, 0, 0), 39.801, 7.372, 1397)
# (565028, 'Candyman', datetime.datetime(2021, 8, 25, 0, 0), 21.165, 6.043, 1500)
# (565310, 'The Farewell', datetime.datetime(2019, 7, 12, 0, 0), 40.47, 7.434, 1360)
# (565426, 'To All the Boys: P.S. I Still Love You', datetime.datetime(2020, 2, 3, 0, 0), 29.788, 6.844, 2482)
# (565770, 'Blue Beetle', datetime.datetime(2023, 8, 16, 0, 0), 108.151, 6.78, 2424)
# (566525, 'Shang-Chi and the Legend of the Ten Rings', datetime.datetime(2021, 9, 1, 0, 0), 83.531, 7.556, 9091)
# (567189, "Tom Clancy's Without Remorse", datetime.datetime(2021, 4, 29, 0, 0), 35.705, 6.983, 2369)
# (567609, 'Ready or Not', datetime.datetime(2019, 8, 21, 0, 0), 61.757, 7.062, 4230)
# (567748, 'The Guilty', datetime.datetime(2021, 9, 24, 0, 0), 43.352, 6.409, 2534)
# (568091, 'Fractured', datetime.datetime(2019, 9, 22, 0, 0), 29.712, 6.725, 2423)
# (568124, 'Encanto', datetime.datetime(2021, 10, 13, 0, 0), 122.244, 7.604, 9236)
# (568160, 'Weathering with You', datetime.datetime(2019, 6, 19, 0, 0), 43.553, 8.005, 2187)
# (568620, 'Snake Eyes: G.I. Joe Origins', datetime.datetime(2021, 7, 22, 0, 0), 40.327, 6.496, 1494)
# (569094, 'Spider-Man: Across the Spider-Verse', datetime.datetime(2023, 5, 31, 0, 0), 176.846, 8.365, 6427)
# (570670, 'The Invisible Man', datetime.datetime(2020, 2, 26, 0, 0), 23.761, 7.118, 5580)
# (572802, 'Aquaman and the Lost Kingdom', datetime.datetime(2023, 12, 20, 0, 0), 168.92, 6.748, 2495)
# (575264, 'Mission: Impossible - Dead Reckoning Part One', datetime.datetime(2023, 7, 8, 0, 0), 154.759, 7.55, 3508)
# (576845, 'Last Night in Soho', datetime.datetime(2021, 10, 21, 0, 0), 32.655, 7.337, 3203)
# (577922, 'Tenet', datetime.datetime(2020, 8, 22, 0, 0), 230.795, 7.186, 9536)
# (578701, 'Those Who Wish Me Dead', datetime.datetime(2021, 5, 5, 0, 0), 28.433, 6.66, 1570)
# (579047, 'Reminiscence', datetime.datetime(2021, 8, 18, 0, 0), 29.188, 6.616, 1697)
# (579974, 'RRR', datetime.datetime(2022, 3, 24, 0, 0), 54.11, 7.764, 1216)
# (580175, 'Another Round', datetime.datetime(2020, 9, 24, 0, 0), 23.853, 7.643, 3104)
# (580489, 'Venom: Let There Be Carnage', datetime.datetime(2021, 9, 30, 0, 0), 120.444, 6.802, 9757)
# (581392, 'Peninsula', datetime.datetime(2020, 7, 15, 0, 0), 30.853, 6.766, 2300)
# (581528, 'The Gangster, the Cop, the Devil', datetime.datetime(2019, 5, 15, 0, 0), 171.615, 7.793, 1050)
# (581600, 'Spenser Confidential', datetime.datetime(2020, 3, 6, 0, 0), 21.977, 6.535, 2218)
# (581726, 'Infinite', datetime.datetime(2021, 9, 9, 0, 0), 54.612, 6.609, 1720)
# (581734, 'Nomadland', datetime.datetime(2021, 1, 29, 0, 0), 28.246, 7.211, 2892)
# (582014, 'Promising Young Woman', datetime.datetime(2020, 12, 13, 0, 0), 29.264, 7.442, 3085)
# (582596, 'The Wrong Missy', datetime.datetime(2020, 5, 13, 0, 0), 20.219, 6.147, 1144)
# (583083, 'The Kissing Booth 2', datetime.datetime(2020, 7, 24, 0, 0), 37.983, 7.657, 4922)
# (585083, 'Hotel Transylvania: Transformania', datetime.datetime(2022, 1, 31, 0, 0), 105.744, 7.096, 2642)
# (585216, 'Escape Room: Tournament of Champions', datetime.datetime(2021, 7, 1, 0, 0), 25.551, 6.6, 1924)
# (585244, 'I Still Believe', datetime.datetime(2020, 3, 12, 0, 0), 17.041, 7.606, 1143)
# (585245, 'Clifford the Big Red Dog', datetime.datetime(2021, 11, 10, 0, 0), 31.678, 7.191, 1695)
# (585511, 'Luck', datetime.datetime(2022, 8, 5, 0, 0), 88.548, 7.785, 1633)
# (587792, 'Palm Springs', datetime.datetime(2020, 7, 10, 0, 0), 33.826, 7.332, 2962)
# (587807, 'Tom & Jerry', datetime.datetime(2021, 2, 10, 0, 0), 54.556, 6.8, 2397)
# (588228, 'The Tomorrow War', datetime.datetime(2021, 9, 3, 0, 0), 93.635, 7.545, 3264)
# (590223, 'Love and Monsters', datetime.datetime(2020, 10, 16, 0, 0), 24.982, 7.312, 3921)
# (591273, 'Fear Street: 1994', datetime.datetime(2021, 6, 28, 0, 0), 30.895, 6.693, 2196)
# (591274, 'Fear Street: 1978', datetime.datetime(2021, 7, 8, 0, 0), 21.992, 7.194, 1833)
# (592350, 'My Hero Academia: Heroes Rising', datetime.datetime(2019, 12, 20, 0, 0), 69.313, 8.173, 1128)
# (592834, 'My Spy', datetime.datetime(2020, 1, 9, 0, 0), 34.716, 6.863, 1099)
# (593643, 'The Menu', datetime.datetime(2022, 11, 17, 0, 0), 45.58, 7.176, 4547)
# (593910, 'Cinderella', datetime.datetime(2021, 9, 3, 0, 0), 50.532, 6.384, 1351)
# (594767, 'Shazam! Fury of the Gods', datetime.datetime(2023, 3, 15, 0, 0), 76.726, 6.556, 2931)
# (597208, 'Nightmare Alley', datetime.datetime(2021, 12, 2, 0, 0), 37.596, 6.993, 2802)
# (597891, 'Kate', datetime.datetime(2021, 9, 10, 0, 0), 125.189, 6.655, 1455)
# (599975, 'Countdown', datetime.datetime(2019, 10, 24, 0, 0), 29.574, 6.258, 2048)
# (600354, 'The Father', datetime.datetime(2020, 12, 23, 0, 0), 44.272, 8.128, 3064)
# (600583, 'The Power of the Dog', datetime.datetime(2021, 10, 25, 0, 0), 25.974, 6.789, 2566)
# (602223, 'The Forever Purge', datetime.datetime(2021, 6, 30, 0, 0), 55.97, 6.96, 2404)
# (602269, 'The Little Things', datetime.datetime(2021, 1, 28, 0, 0), 32.917, 6.3, 2383)
# (602734, 'Spiral: From the Book of Saw', datetime.datetime(2021, 5, 12, 0, 0), 44.607, 5.989, 1911)
# (603692, 'John Wick: Chapter 4', datetime.datetime(2023, 3, 22, 0, 0), 252.838, 7.741, 6045)
# (605116, 'Project Power', datetime.datetime(2020, 8, 14, 0, 0), 27.238, 6.465, 2772)
# (606856, 'Togo', datetime.datetime(2019, 12, 20, 0, 0), 23.846, 8.149, 1950)
# (607259, 'Fatherhood', datetime.datetime(2021, 6, 18, 0, 0), 28.309, 7.543, 1353)
# (609681, 'The Marvels', datetime.datetime(2023, 11, 8, 0, 0), 189.937, 6.122, 2413)
# (610150, 'Dragon Ball Super: Super Hero', datetime.datetime(2022, 6, 11, 0, 0), 55.333, 7.907, 2756)
# (610253, 'Halloween Kills', datetime.datetime(2021, 10, 14, 0, 0), 36.962, 6.451, 2573)
# (613504, 'After We Collided', datetime.datetime(2020, 9, 2, 0, 0), 85.808, 7.188, 5216)
# (614409, 'To All the Boys: Always and Forever', datetime.datetime(2021, 2, 12, 0, 0), 24.88, 7.569, 1851)
# (614479, 'Insidious: The Red Door', datetime.datetime(2023, 7, 5, 0, 0), 72.282, 6.6, 1595)
# (614696, '#Alive', datetime.datetime(2020, 6, 24, 0, 0), 29.286, 7.255, 1733)
# (614917, 'King Richard', datetime.datetime(2021, 11, 18, 0, 0), 28.514, 7.662, 2355)
# (614930, 'Teenage Mutant Ninja Turtles: Mutant Mayhem', datetime.datetime(2023, 7, 31, 0, 0), 83.392, 7.247, 1194)
# (614934, 'Elvis', datetime.datetime(2022, 6, 22, 0, 0), 42.555, 7.542, 3229)
# (615457, 'Nobody', datetime.datetime(2021, 3, 18, 0, 0), 89.04, 7.967, 6820)
# (615469, 'Spiderhead', datetime.datetime(2022, 6, 17, 0, 0), 29.211, 5.798, 1474)
# (615643, 'Minari', datetime.datetime(2021, 2, 12, 0, 0), 32.267, 7.351, 1548)
# (615656, 'Meg 2: The Trench', datetime.datetime(2023, 8, 2, 0, 0), 150.411, 6.544, 3200)
# (615658, 'Awake', datetime.datetime(2021, 6, 9, 0, 0), 20.886, 5.9, 1034)
# (615665, 'Holidate', datetime.datetime(2020, 10, 27, 0, 0), 25.897, 7.033, 2110)
# (615777, 'Babylon', datetime.datetime(2022, 12, 22, 0, 0), 135.335, 7.41, 2857)
# (616037, 'Thor: Love and Thunder', datetime.datetime(2022, 7, 6, 0, 0), 115.028, 6.463, 7259)
# (616651, 'Stillwater', datetime.datetime(2021, 7, 29, 0, 0), 32.448, 6.635, 1173)
# (616820, 'Halloween Ends', datetime.datetime(2022, 10, 12, 0, 0), 37.682, 6.129, 1648)
# (617502, 'Jolt', datetime.datetime(2021, 7, 15, 0, 0), 20.82, 6.582, 1205)
# (617653, 'The Last Duel', datetime.datetime(2021, 10, 13, 0, 0), 28.015, 7.444, 3235)
# (618162, 'The Harder They Fall', datetime.datetime(2021, 10, 22, 0, 0), 22.057, 6.642, 1003)
# (618344, 'Justice League Dark: Apokolips War', datetime.datetime(2020, 5, 5, 0, 0), 32.611, 8.234, 1426)
# (619264, 'The Platform', datetime.datetime(2019, 11, 8, 0, 0), 49.599, 6.98, 6709)
# (619730, "Don't Worry Darling", datetime.datetime(2022, 9, 21, 0, 0), 34.384, 6.801, 2279)
# (619778, 'Malignant', datetime.datetime(2021, 9, 1, 0, 0), 46.532, 6.81, 2203)
# (623491, 'The Babysitter: Killer Queen', datetime.datetime(2020, 9, 10, 0, 0), 18.223, 6.338, 1574)
# (624860, 'The Matrix Resurrections', datetime.datetime(2021, 12, 16, 0, 0), 72.267, 6.428, 5512)
# (625450, 'Tall Girl', datetime.datetime(2019, 9, 13, 0, 0), 23.283, 6.33, 1836)
# (625568, 'Unhinged', datetime.datetime(2020, 7, 16, 0, 0), 34.376, 6.45, 2184)
# (626735, 'Dog', datetime.datetime(2022, 2, 17, 0, 0), 32.68, 7.334, 1464)
# (629176, 'Samaritan', datetime.datetime(2022, 8, 25, 0, 0), 48.887, 6.726, 1907)
# (629542, 'The Bad Guys', datetime.datetime(2022, 3, 17, 0, 0), 44.988, 7.571, 1938)
# (630240, 'Titane', datetime.datetime(2021, 7, 14, 0, 0), 105.52, 6.406, 1354)
# (630586, 'Wrong Turn', datetime.datetime(2021, 1, 26, 0, 0), 85.691, 6.0, 1084)
# (631842, 'Knock at the Cabin', datetime.datetime(2023, 2, 1, 0, 0), 53.64, 6.294, 2375)
# (631843, 'Old', datetime.datetime(2021, 7, 21, 0, 0), 37.356, 6.353, 4228)
# (632357, 'The Unholy', datetime.datetime(2021, 3, 31, 0, 0), 45.328, 6.612, 2087)
# (634528, 'The Marksman', datetime.datetime(2021, 1, 15, 0, 0), 41.021, 6.846, 1522)
# (634649, 'Spider-Man: No Way Home', datetime.datetime(2021, 12, 15, 0, 0), 178.436, 7.964, 19568)
# (635302, 'Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train', datetime.datetime(2020, 10, 16, 0, 0), 192.505, 8.229, 3756)
# (635731, 'Pig', datetime.datetime(2021, 7, 16, 0, 0), 21.772, 6.7, 1318)
# (635910, 'The Last Voyage of the Demeter', datetime.datetime(2023, 8, 9, 0, 0), 60.492, 6.889, 1387)
# (637534, 'The Stronghold', datetime.datetime(2021, 8, 18, 0, 0), 20.719, 7.413, 1216)
# (637649, 'Wrath of Man', datetime.datetime(2021, 4, 22, 0, 0), 106.76, 7.642, 5080)
# (637920, 'Miracle in Cell No. 7', datetime.datetime(2019, 10, 10, 0, 0), 34.256, 8.3, 4327)
# (638597, 'Yes Day', datetime.datetime(2021, 3, 12, 0, 0), 24.822, 6.7, 1146)
# (638974, 'Murder Mystery 2', datetime.datetime(2023, 3, 28, 0, 0), 37.127, 6.439, 1608)
# (639721, 'The Addams Family 2', datetime.datetime(2021, 10, 1, 0, 0), 39.071, 7.011, 1240)
# (639933, 'The Northman', datetime.datetime(2022, 4, 7, 0, 0), 69.08, 7.061, 4091)
# (640146, 'Ant-Man and the Wasp: Quantumania', datetime.datetime(2023, 2, 15, 0, 0), 76.716, 6.348, 4751)
# (642885, 'Hocus Pocus 2', datetime.datetime(2022, 9, 30, 0, 0), 68.698, 7.257, 1589)
# (644495, 'House of Gucci', datetime.datetime(2021, 11, 24, 0, 0), 23.203, 6.605, 3007)
# (644583, 'The Mauritanian', datetime.datetime(2021, 2, 12, 0, 0), 30.385, 7.431, 1041)
# (645886, 'The Unforgivable', datetime.datetime(2021, 11, 24, 0, 0), 38.874, 7.446, 1761)
# (646207, 'The Ice Road', datetime.datetime(2021, 6, 24, 0, 0), 27.106, 6.843, 1623)
# (646380, "Don't Look Up", datetime.datetime(2021, 12, 7, 0, 0), 45.702, 7.101, 7928)
# (646385, 'Scream', datetime.datetime(2022, 1, 12, 0, 0), 57.183, 6.668, 3125)
# (646389, 'Plane', datetime.datetime(2023, 1, 12, 0, 0), 50.807, 6.969, 2103)
# (648579, 'The Unbearable Weight of Massive Talent', datetime.datetime(2022, 4, 20, 0, 0), 31.449, 6.774, 1873)
# (649609, 'Renfield', datetime.datetime(2023, 4, 7, 0, 0), 32.007, 6.558, 1472)
# (653346, 'Kingdom of the Planet of the Apes', datetime.datetime(2024, 5, 8, 0, 0), 1777.192, 6.863, 1291)
# (656690, 'The Social Dilemma', datetime.datetime(2020, 1, 26, 0, 0), 20.538, 7.469, 1537)
# (660120, 'The Worst Person in the World', datetime.datetime(2021, 10, 13, 0, 0), 28.657, 7.5, 1256)
# (661374, 'Glass Onion: A Knives Out Mystery', datetime.datetime(2022, 11, 12, 0, 0), 37.978, 7.053, 5248)
# (663712, 'Terrifier 2', datetime.datetime(2022, 10, 6, 0, 0), 112.805, 6.767, 1669)
# (664413, '365 Days', datetime.datetime(2020, 2, 7, 0, 0), 32.183, 7.048, 8804)
# (664469, 'Amsterdam', datetime.datetime(2022, 9, 27, 0, 0), 30.02, 6.053, 1406)
# (664767, "Mortal Kombat Legends: Scorpion's Revenge", datetime.datetime(2020, 4, 12, 0, 0), 51.908, 8.112, 1346)
# (666277, 'Past Lives', datetime.datetime(2023, 6, 2, 0, 0), 74.752, 7.791, 1370)
# (667520, 'A Whisker Away', datetime.datetime(2020, 6, 18, 0, 0), 35.851, 7.896, 1338)
# (667538, 'Transformers: Rise of the Beasts', datetime.datetime(2023, 6, 6, 0, 0), 180.423, 7.328, 4337)
# (670292, 'The Creator', datetime.datetime(2023, 9, 27, 0, 0), 102.019, 7.106, 2756)
# (674324, 'The Banshees of Inisherin', datetime.datetime(2022, 10, 20, 0, 0), 25.689, 7.459, 2572)
# (675353, 'Sonic the Hedgehog 2', datetime.datetime(2022, 3, 30, 0, 0), 116.584, 7.522, 4754)
# (675445, 'PAW Patrol: The Movie', datetime.datetime(2021, 8, 9, 0, 0), 75.44, 7.403, 1196)
# (677179, 'Creed III', datetime.datetime(2023, 3, 1, 0, 0), 115.47, 7.131, 2383)
# (678512, 'Sound of Freedom', datetime.datetime(2023, 7, 3, 0, 0), 108.821, 8.022, 2228)
# (682507, 'Where the Crawdads Sing', datetime.datetime(2022, 7, 14, 0, 0), 21.883, 7.546, 1607)
# (691179, 'Friends: The Reunion', datetime.datetime(2021, 5, 27, 0, 0), 23.193, 7.87, 1156)
# (693134, 'Dune: Part Two', datetime.datetime(2024, 2, 27, 0, 0), 413.319, 8.168, 4728)
# (695721, 'The Hunger Games: The Ballad of Songbirds & Snakes', datetime.datetime(2023, 11, 15, 0, 0), 124.447, 7.135, 2306)
# (696806, 'The Adam Project', datetime.datetime(2022, 3, 11, 0, 0), 43.08, 7.045, 4141)
# (697843, 'Extraction 2', datetime.datetime(2023, 6, 9, 0, 0), 74.77, 7.463, 2287)
# (698948, 'Thirteen Lives', datetime.datetime(2022, 7, 18, 0, 0), 31.274, 7.899, 1195)
# (700391, '65', datetime.datetime(2023, 3, 2, 0, 0), 40.311, 6.009, 2199)
# (705861, 'Hustle', datetime.datetime(2022, 6, 3, 0, 0), 46.637, 7.8, 2415)
# (705996, 'Decision to Leave', datetime.datetime(2022, 6, 29, 0, 0), 48.104, 7.363, 1108)
# (707886, 'Feel the Beat', datetime.datetime(2020, 6, 19, 0, 0), 17.932, 7.589, 1093)
# (713704, 'Evil Dead Rise', datetime.datetime(2023, 4, 12, 0, 0), 110.93, 6.955, 2872)
# (715931, 'Emancipation', datetime.datetime(2022, 12, 2, 0, 0), 45.155, 7.85, 1068)
# (718032, 'Licorice Pizza', datetime.datetime(2021, 11, 26, 0, 0), 38.557, 6.976, 2146)
# (718789, 'Lightyear', datetime.datetime(2022, 6, 15, 0, 0), 44.473, 6.995, 3315)
# (718930, 'Bullet Train', datetime.datetime(2022, 8, 3, 0, 0), 77.185, 7.5, 5801)
# (724209, 'Heart of Stone', datetime.datetime(2023, 8, 9, 0, 0), 59.656, 6.828, 1586)
# (724495, 'The Woman King', datetime.datetime(2022, 9, 16, 0, 0), 49.145, 7.68, 1947)
# (725201, 'The Gray Man', datetime.datetime(2022, 7, 13, 0, 0), 47.005, 6.963, 3470)
# (726209, 'Leave the World Behind', datetime.datetime(2023, 11, 22, 0, 0), 49.137, 6.46, 2240)
# (726759, 'Tetris', datetime.datetime(2023, 3, 15, 0, 0), 34.779, 7.733, 1193)
# (727745, 'The Kissing Booth 3', datetime.datetime(2021, 8, 11, 0, 0), 34.837, 6.906, 1842)
# (736526, 'Troll', datetime.datetime(2022, 12, 1, 0, 0), 40.868, 6.637, 1633)
# (739405, 'Operation Fortune: Ruse de Guerre', datetime.datetime(2023, 1, 4, 0, 0), 60.894, 6.513, 1368)
# (740985, 'Borat Subsequent Moviefilm', datetime.datetime(2020, 10, 23, 0, 0), 29.57, 6.464, 2451)
# (744275, 'After We Fell', datetime.datetime(2021, 9, 1, 0, 0), 94.26, 7.1, 2496)
# (744276, 'After Ever Happy', datetime.datetime(2022, 8, 24, 0, 0), 83.435, 6.807, 1171)
# (746036, 'The Fall Guy', datetime.datetime(2024, 4, 24, 0, 0), 519.222, 7.3, 1460)
# (747188, 'Asteroid City', datetime.datetime(2023, 6, 8, 0, 0), 47.936, 6.492, 1701)
# (752623, 'The Lost City', datetime.datetime(2022, 3, 24, 0, 0), 44.907, 6.521, 3438)
# (753342, 'Napoleon', datetime.datetime(2023, 11, 22, 0, 0), 118.811, 6.436, 2197)
# (755566, 'Day Shift', datetime.datetime(2022, 8, 12, 0, 0), 44.829, 6.799, 1854)
# (755812, 'Miraculous World: New York, United HeroeZ', datetime.datetime(2020, 9, 25, 0, 0), 42.141, 8.121, 1070)
# (756999, 'The Black Phone', datetime.datetime(2022, 6, 22, 0, 0), 61.049, 7.616, 4681)
# (758009, 'Shotgun Wedding', datetime.datetime(2022, 12, 28, 0, 0), 55.722, 6.328, 1117)
# (758323, "The Pope's Exorcist", datetime.datetime(2023, 4, 5, 0, 0), 79.762, 7.01, 2543)
# (758866, 'Drive My Car', datetime.datetime(2021, 8, 18, 0, 0), 21.009, 7.406, 1197)
# (760104, 'X', datetime.datetime(2022, 3, 17, 0, 0), 194.566, 6.737, 2887)
# (760161, 'Orphan: First Kill', datetime.datetime(2022, 7, 27, 0, 0), 46.275, 6.659, 2024)
# (760741, 'Beast', datetime.datetime(2022, 8, 11, 0, 0), 66.425, 6.644, 1458)
# (760883, 'Blood Red Sky', datetime.datetime(2021, 7, 23, 0, 0), 27.695, 6.878, 1486)
# (762430, 'Retribution', datetime.datetime(2023, 8, 23, 0, 0), 91.899, 6.7, 1071)
# (762504, 'Nope', datetime.datetime(2022, 7, 20, 0, 0), 47.71, 6.851, 3829)
# (762975, 'Purple Hearts', datetime.datetime(2022, 7, 29, 0, 0), 61.165, 8.119, 2409)
# (763215, 'Damsel', datetime.datetime(2024, 3, 7, 0, 0), 177.237, 7.104, 1920)
# (763285, 'Ambulance', datetime.datetime(2022, 3, 16, 0, 0), 41.303, 6.656, 2007)
# (766507, 'Prey', datetime.datetime(2022, 8, 2, 0, 0), 134.644, 7.7, 6381)
# (774752, 'The Guardians of the Galaxy Holiday Special', datetime.datetime(2022, 11, 25, 0, 0), 30.909, 7.173, 1878)
# (774825, 'The Ice Age Adventures of Buck Wild', datetime.datetime(2022, 1, 28, 0, 0), 64.38, 6.628, 1659)
# (775996, 'Outside the Wire', datetime.datetime(2021, 1, 15, 0, 0), 22.843, 6.36, 1751)
# (776503, 'CODA', datetime.datetime(2021, 8, 13, 0, 0), 39.846, 7.943, 2112)
# (779782, 'The School for Good and Evil', datetime.datetime(2022, 10, 19, 0, 0), 45.184, 7.1, 1178)
# (785084, 'The Whale', datetime.datetime(2022, 12, 9, 0, 0), 65.356, 7.864, 3631)
# (786892, 'Furiosa: A Mad Max Saga', datetime.datetime(2024, 5, 22, 0, 0), 4115.719, 7.7, 1688)
# (787699, 'Wonka', datetime.datetime(2023, 12, 6, 0, 0), 233.137, 7.165, 3134)
# (787752, 'Fresh', datetime.datetime(2022, 3, 3, 0, 0), 33.141, 6.978, 1475)
# (791177, 'Bones and All', datetime.datetime(2022, 11, 18, 0, 0), 25.13, 7.069, 1259)
# (791373, "Zack Snyder's Justice League", datetime.datetime(2021, 3, 18, 0, 0), 98.433, 8.157, 9749)
# (792307, 'Poor Things', datetime.datetime(2023, 12, 7, 0, 0), 151.889, 7.781, 3601)
# (795514, 'The Fallout', datetime.datetime(2021, 3, 17, 0, 0), 45.677, 7.624, 1051)
# (796185, "The Three Musketeers: D'Artagnan", datetime.datetime(2023, 4, 5, 0, 0), 46.525, 7.003, 1064)
# (796499, 'Army of Thieves', datetime.datetime(2021, 10, 29, 0, 0), 33.356, 6.843, 1937)
# (799876, 'The Outfit', datetime.datetime(2022, 2, 25, 0, 0), 43.091, 7.104, 1012)
# (800158, 'The Killer', datetime.datetime(2023, 10, 25, 0, 0), 40.022, 6.584, 1917)
# (800815, 'The Pale Blue Eye', datetime.datetime(2022, 12, 22, 0, 0), 21.348, 6.848, 1736)
# (800939, 'Ticket to Paradise', datetime.datetime(2022, 9, 8, 0, 0), 19.176, 6.524, 1093)
# (804095, 'The Fabelmans', datetime.datetime(2022, 11, 11, 0, 0), 82.69, 7.64, 2176)
# (804150, 'Cocaine Bear', datetime.datetime(2023, 2, 22, 0, 0), 86.965, 6.1, 1883)
# (810693, 'Jujutsu Kaisen 0', datetime.datetime(2021, 12, 24, 0, 0), 74.851, 8.186, 1314)
# (817758, 'TÁR', datetime.datetime(2022, 9, 23, 0, 0), 31.563, 7.1, 1156)
# (818397, 'Memory', datetime.datetime(2022, 4, 28, 0, 0), 54.023, 6.822, 1442)
# (818647, 'Through My Window', datetime.datetime(2022, 2, 4, 0, 0), 86.629, 7.381, 3023)
# (820609, 'No One Will Save You', datetime.datetime(2023, 9, 22, 0, 0), 63.589, 6.695, 1057)
# (823464, 'Godzilla x Kong: The New Empire', datetime.datetime(2024, 3, 27, 0, 0), 1029.737, 7.212, 3005)
# (823625, 'Blacklight', datetime.datetime(2022, 2, 10, 0, 0), 29.996, 6.187, 1058)
# (829280, 'Enola Holmes 2', datetime.datetime(2022, 11, 30, 0, 0), 30.653, 7.406, 1331)
# (829557, '365 Days: This Day', datetime.datetime(2022, 4, 27, 0, 0), 157.383, 5.878, 1424)
# (829560, 'The Next 365 Days', datetime.datetime(2022, 8, 19, 0, 0), 111.908, 6.425, 1025)
# (833425, 'No Exit', datetime.datetime(2022, 2, 24, 0, 0), 33.609, 6.9, 1083)
# (836225, 'The Exorcism of God', datetime.datetime(2022, 3, 11, 0, 0), 125.481, 7.107, 1012)
# (840326, 'Sisu', datetime.datetime(2022, 9, 9, 0, 0), 67.205, 7.483, 1955)
# (840430, 'The Holdovers', datetime.datetime(2023, 10, 27, 0, 0), 48.062, 7.716, 1291)
# (843527, 'The Idea of You', datetime.datetime(2024, 5, 2, 0, 0), 213.238, 7.395, 1128)
# (848326, 'Rebel Moon - Part One: A Child of Fire', datetime.datetime(2023, 12, 15, 0, 0), 85.759, 6.347, 1907)
# (848538, 'Argylle', datetime.datetime(2024, 1, 31, 0, 0), 105.345, 6.147, 1098)
# (866398, 'The Beekeeper', datetime.datetime(2024, 1, 8, 0, 0), 218.487, 7.392, 2610)
# (868759, 'Ghosted', datetime.datetime(2023, 4, 18, 0, 0), 77.987, 6.963, 1667)
# (872585, 'Oppenheimer', datetime.datetime(2023, 7, 19, 0, 0), 293.8, 8.093, 8458)
# (877269, 'Strange World', datetime.datetime(2022, 11, 23, 0, 0), 60.596, 6.357, 1197)
# (882569, "Guy Ritchie's The Covenant", datetime.datetime(2023, 4, 19, 0, 0), 82.308, 7.778, 2289)
# (882598, 'Smile', datetime.datetime(2022, 9, 23, 0, 0), 65.363, 6.663, 2841)
# (884605, 'No Hard Feelings', datetime.datetime(2023, 6, 15, 0, 0), 61.491, 6.8, 2748)
# (894205, 'Werewolf by Night', datetime.datetime(2022, 9, 25, 0, 0), 23.714, 6.987, 1198)
# (899082, 'Harry Potter 20th Anniversary: Return to Hogwarts', datetime.datetime(2022, 1, 1, 0, 0), 37.277, 7.3, 3225)
# (899112, 'Violent Night', datetime.datetime(2022, 11, 30, 0, 0), 45.575, 7.335, 1996)
# (906126, 'Society of the Snow', datetime.datetime(2023, 12, 15, 0, 0), 61.423, 8.048, 2655)
# (913290, 'Barbarian', datetime.datetime(2022, 9, 8, 0, 0), 45.532, 6.839, 2233)
# (915935, 'Anatomy of a Fall', datetime.datetime(2023, 8, 23, 0, 0), 63.892, 7.59, 2112)
# (916224, 'Suzume', datetime.datetime(2022, 11, 11, 0, 0), 67.491, 7.972, 1176)
# (926393, 'The Equalizer 3', datetime.datetime(2023, 8, 30, 0, 0), 119.815, 7.349, 2723)
# (929590, 'Civil War', datetime.datetime(2024, 4, 10, 0, 0), 915.977, 7.0, 1779)
# (930094, 'Red, White & Royal Blue', datetime.datetime(2023, 7, 27, 0, 0), 61.359, 7.979, 1186)
# (930564, 'Saltburn', datetime.datetime(2023, 11, 16, 0, 0), 54.647, 7.0, 2081)
# (934433, 'Scream VI', datetime.datetime(2023, 3, 8, 0, 0), 71.312, 7.05, 2404)
# (937278, 'A Man Called Otto', datetime.datetime(2022, 12, 28, 0, 0), 50.158, 7.759, 2411)
# (937287, 'Challengers', datetime.datetime(2024, 4, 18, 0, 0), 135.682, 7.195, 1082)
# (940551, 'Migration', datetime.datetime(2023, 12, 6, 0, 0), 409.833, 7.462, 1494)
# (940721, 'Godzilla Minus One', datetime.datetime(2023, 11, 3, 0, 0), 307.713, 7.578, 1827)
# (945729, 'A Haunting in Venice', datetime.datetime(2023, 9, 13, 0, 0), 47.517, 6.677, 2097)
# (949423, 'Pearl', datetime.datetime(2022, 9, 16, 0, 0), 60.636, 7.295, 1501)
# (951491, 'Saw X', datetime.datetime(2023, 9, 27, 0, 0), 100.549, 7.263, 1761)
# (955916, 'Lift', datetime.datetime(2024, 1, 10, 0, 0), 98.231, 6.522, 1072)
# (964980, 'Air', datetime.datetime(2023, 4, 5, 0, 0), 36.347, 7.355, 1768)
# (965150, 'Aftersun', datetime.datetime(2022, 10, 21, 0, 0), 44.479, 7.687, 1251)
# (967847, 'Ghostbusters: Frozen Empire', datetime.datetime(2024, 3, 20, 0, 0), 224.752, 6.7, 1062)
# (968051, 'The Nun II', datetime.datetime(2023, 9, 6, 0, 0), 121.77, 6.789, 1856)
# (976573, 'Elemental', datetime.datetime(2023, 6, 14, 0, 0), 226.137, 7.652, 4153)
# (980489, 'Gran Turismo', datetime.datetime(2023, 8, 9, 0, 0), 88.043, 7.845, 2451)
# (985939, 'Fall', datetime.datetime(2022, 8, 11, 0, 0), 76.273, 7.2, 3662)
# (1008042, 'Talk to Me', datetime.datetime(2023, 7, 26, 0, 0), 136.413, 7.159, 2671)
# (1010581, 'My Fault', datetime.datetime(2023, 6, 8, 0, 0), 521.216, 7.967, 2651)
# (1011985, 'Kung Fu Panda 4', datetime.datetime(2024, 3, 2, 0, 0), 757.674, 7.128, 2190)
# (1022789, 'Inside Out 2', datetime.datetime(2024, 6, 11, 0, 0), 4128.506, 7.71, 1288)
# (1022796, 'Wish', datetime.datetime(2023, 11, 13, 0, 0), 229.021, 6.401, 1300)
# (1029575, 'The Family Plan', datetime.datetime(2023, 12, 14, 0, 0), 138.257, 7.291, 1230)
# (1071215, 'Thanksgiving', datetime.datetime(2023, 11, 16, 0, 0), 75.575, 6.586, 1012)
# (1072790, 'Anyone But You', datetime.datetime(2023, 12, 21, 0, 0), 172.787, 7.045, 1688)
# (1075794, 'Leo', datetime.datetime(2023, 11, 17, 0, 0), 109.912, 7.479, 1091)
# (1151534, 'Nowhere', datetime.datetime(2023, 9, 29, 0, 0), 87.766, 7.426, 1255)
